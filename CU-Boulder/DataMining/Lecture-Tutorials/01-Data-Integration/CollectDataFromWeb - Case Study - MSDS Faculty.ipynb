# %% [markdown]
# # Introduction to Web Scraping using beautifulsoup

# %% [markdown]
# Let's say you want to extract information from the websites for further analysis, for example, collecting news headlines from a particular news agency for sentiment analysis, you will have to use tools to do the job. Web scraping or web data extraction is the process of extracting information from the websites. There are many tools that is used to scrape data such as beautiful soup, scrapy, Urllib3, selenium etc. In this tutorial we will be using beautiful soup to extract the data.

# %% [markdown]
# ### beautifulsoup

# %% [markdown]
# beautifulsoup is a python library used to parse HTML and XML documents. beautifulsoup uses a tree structure to identify the data and offers an automated encoding conversions, that makes it easier to handle the web data.

# %% [markdown]
# ### Install beautifulsoup

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4) (2.3.2.post1)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# Sample HTML Tree

# %% [markdown]
# Below is the sample HTML tree(truncated) for the website - https://web.ics.purdue.edu/~gchopra/class/public/pages/webdesign/05_simple.html (This is a publicly hosted website by Purdue University used for generating the tree)

# %% [markdown]
# ![Sample HTML](image-20230119-090623.png)

# %% [markdown]
# Do you also want to generate a tree to for a web page?

# %% [markdown]
# Then install HTML Tree Generator as an extension to chrome. Then click on the added extension to generate tree for a particular webpage.

# %% [markdown]
# ### Get Complete HTML Data

# %%
from bs4 import BeautifulSoup
import requests

website = requests.get('https://www.colorado.edu/program/data-science/faculty')
print(website)
print(website.text)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html  lang="en" dir="ltr"
#   xmlns:og="http://ogp.me/ns#"><!--<![endif]-->
#
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <link rel="shortcut icon" href="https://www.colorado.edu/program/data-science/profiles/express/themes/cumodern/favicon.ico" type="image/vnd.microsoft.icon" />
# <link href="https://www.colorado.edu/program/data-science/feed/rss.xml" rel="alternate" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <link rel="apple-touch-icon" sizes="57x57" href="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/apple-icon-57x57.png" />
# <link rel="apple-touch-icon" sizes="72x72" href="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/apple-icon-72x72.png" />
# <link rel="apple-touch-icon" sizes="114x114" href="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/apple-icon-114x114.png" />
# <link rel="apple-touch-icon" sizes="144x144" href="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/apple-icon-144x144.png" />
# <link href="//fonts.googleapis.com" rel="preconnect" />
# <meta name="description" content="The MS-DS is a truly interdisciplinary program, with faculty in Computer Science, Applied Mathematics, Information Science, and more. Data science faculty members are housed in Applied Mathematics, Computer Science, Information Science, and other departments across campus.    " />
# <link href="//fonts.gstatic.com" rel="preconnect" crossorigin="" />
# <link href="//fonts.googleapis.com/css2?family=Roboto+Condensed:wght@700&amp;family=Roboto:wght@400;700&amp;display=swap" rel="stylesheet" type="text/css" />
# <meta name="generator" content="Drupal 7 (https://www.drupal.org)" />
# <link rel="canonical" href="https://www.colorado.edu/program/data-science/faculty" />
# <link rel="shortlink" href="https://www.colorado.edu/program/data-science/node/169" />
# <meta property="og:site_name" content="Master of Science in Data Science" />
# <meta property="og:type" content="article" />
# <meta property="og:url" content="https://www.colorado.edu/program/data-science/faculty" />
# <meta property="og:title" content="Our People" />
# <meta property="og:description" content="The MS-DS is a truly interdisciplinary program, with faculty in Computer Science, Applied Mathematics, Information Science, and more. Data science faculty members are housed in Applied Mathematics, Computer Science, Information Science, and other departments across campus.    " />
# <meta property="og:updated_time" content="2022-09-23T13:31:12-06:00" />
# <meta name="twitter:card" content="summary" />
# <meta name="twitter:url" content="https://www.colorado.edu/program/data-science/faculty" />
# <meta name="twitter:title" content="Our People" />
# <meta name="twitter:description" content="The MS-DS is a truly interdisciplinary program, with faculty in Computer Science, Applied Mathematics, Information Science, and more. Data science faculty members are housed in Applied Mathematics," />
# <meta property="article:published_time" content="2021-03-11T10:22:39-07:00" />
# <meta property="article:modified_time" content="2022-09-23T13:31:12-06:00" />
#   <title>Our People | Master of Science in Data Science | University of Colorado Boulder</title>
#
#       <meta name="MobileOptimized" content="width">
#     <meta name="HandheldFriendly" content="true">
#     <meta name="viewport" content="width=device-width">
#   <meta http-equiv="cleartype" content="on">
#
#   <style type="text/css" media="screen">
# @import url("https://www.colorado.edu/program/data-science/modules/system/system.base.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/system/system.menus.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/system/system.messages.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/system/system.theme.css?rm4bdq");
# </style>
# <style type="text/css" media="screen">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/themes/base/minified/jquery.ui.core.min.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/themes/base/minified/jquery.ui.accordion.min.css?rm4bdq");
# </style>
# <style type="text/css" media="screen">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/modules/cu_article_slider/css/cu-article-slider.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_campus_news_bundle/cu_campus_news/css/cu-campus-news.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_dashboard_seo/css/cu-dashboard-seo.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_expandable/css/cu-expandable.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_inactive_users/css/cu-inactive-users.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_js_includes/css/cu-js-includes.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_profile_module_manager/css/cu-profile-module-manager.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/cu_related_articles/css/cu-related-articles.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_rss/css/cu-rss.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_share/css/cu-share.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_wysiwyg/cu-wysiwyg.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/date/date_api/date.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/date/date_popup/themes/datepicker.1.7.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_add_content/css/express-add-content.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_block_designer/css/express-block-designer.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_block_designer/modules/express_block_designer_menu/css/exbd-menu.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_collections_bundle/css/express-collections-bundle.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_layout/css/express-layout-admin.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_localist_bundle/css/express-localist-bundle.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_localist_bundle/css/express-localist-bundle-theme.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/fences/field.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/fitvids/fitvids.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/google_cse/google_cse.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/node/node.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/rave_alerts/css/rave_alerts.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/site_navigation_menus/css/site-navigation-menus.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/user/user.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/video_filter/video_filter.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/views/css/views.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_users/css/cu-users.css?rm4bdq");
# </style>
# <style type="text/css" media="screen">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/colorbox/styles/stockholmsyndrome/colorbox_style.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/context_accordion/context_accordion.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/ctools/css/ctools.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/libraries/flickity/css/flickity.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/libraries/fontawesome/css/font-awesome.min.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/files_undo_remove/files_undo_remove.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/backstretch/backstretch.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_block_row/css/cu-block-row.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_block_section/css/cu-block-section.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_facebook_activity/cu_facebook_activity.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_feature_callout/css/cu_feature_callout.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_feature_callout/css/feature-callout-block-designer.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_give_buttons/styles/give-button.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_hero_unit/css/cu_hero_unit.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_menu_icon/cu_menu_icon.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_publications_bundle/cu_publication/css/cu-publication.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_rss_block/css/cu-rss-block.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_search/css/cu-search.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_shortcodes/css/cu_shortcodes.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_shortcodes/css/cu-shortcodes-columns.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_site_info/site_info.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_social_links/css/social_links.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_twitter_feed/cu_twitter_feed.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_video_hero_unit_bundle/css/cu_video_hero_unit.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_video_reveal/css/cu-video-reveal.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_layout/css/express-layout.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_settings/css/express-settings.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/files/css/files.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/profile_module_manager/css/profile-module-manager.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/css/cu-article.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/css/cu-article-grid.css?rm4bdq");
# </style>
# <style type="text/css" media="screen">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/css/owl.carousel.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_faq/css/cu_faq.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_page/cu-page.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_theme_picker/express_theme_picker.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/people_content_type/css/people_content_type.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/photo_gallery/css/photo-gallery.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_back_to_top/cu_back_to_top.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/sites/default/files/honeypot/honeypot.css?rm4bdq");
# </style>
# <style type="text/css" media="screen">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/css/ucb.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/themes/cumodern/css/modern-styles.css?rm4bdq");
# </style>
# <style type="text/css" media="print">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/css/ucb-print.css?rm4bdq");
# </style>
#   <script type="text/javascript" defer="defer" src="https://www.colorado.edu/program/data-science/sites/default/files/google_tag/google_tag.script.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/libraries/modernizr/modernizr.min.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/jquery/1.9/jquery.min.js?v=1.9.1"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.migrateMute=true;jQuery.migrateTrace=false;
# //--><!]]>
# </script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/jquery-migrate/1/jquery-migrate.min.js?v=1"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/misc/jquery-extend-3.4.0.js?v=1.9.1"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/misc/jquery-html-prefilter-3.5.0-backport.js?v=1.9.1"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/misc/jquery.once.js?v=1.2"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/misc/drupal.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/libraries/fitvids/jquery.fitvids.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/libraries/match-height/jquery.matchHeight-min.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/libraries/waypoints/waypoint.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/ui/minified/jquery.ui.core.min.js?v=1.10.2"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/ui/minified/jquery.ui.widget.min.js?v=1.10.2"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/ui/minified/jquery.ui.accordion.min.js?v=1.10.2"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_colorbox/js/cu-colorbox.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_expandable/js/expandable.plugin.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_expandable/js/cu-expandable.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_share/js/cu_share.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_video_hero_unit_bundle/js/cu-video-hero.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_collections_bundle/js/express-collections-bundle.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_layout/js/express-layout.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/fitvids/fitvids.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/google_cse/google_cse.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/site_navigation_menus/js/site-navigation-menus.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/libraries/colorbox/jquery.colorbox-min.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/colorbox/js/colorbox.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/colorbox/styles/stockholmsyndrome/colorbox_style.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/context_accordion/context_accordion.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/libraries/flickity/js/flickity.pkgd.min.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/modules/cu_article_slider/js/cu-article-slider.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/files_undo_remove/files_undo_remove.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/libraries/backstretch/jquery.backstretch.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/rave_alerts/js/rave_alerts.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_block_section/js/cu-block-section.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_block_section/js/parallaxie.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_shortcodes/js/cu_shortcodes.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_shortcodes/js/counter.js?rm4bdq"></script>
# <script type="text/javascript" src="//www.youtube.com/iframe_api"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/google_analytics/googleanalytics.js?rm4bdq"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-105731679-1", {"cookieDomain":"auto"});ga("create", "UA-142322394-2", "auto", {"name":"customTracker0"});ga("set", "anonymizeIp", true);ga("set", "dimension1", "169");ga("set", "dimension2", "Our People");ga("set", "dimension3", "People List Page");ga("set", "dimension4", "Thu, 03\/11\/2021 - 10:22");ga("customTracker0.set", "anonymizeIp", true);ga("customTracker0.set", "dimension1", "169");ga("customTracker0.set", "dimension2", "Our People");ga("customTracker0.set", "dimension3", "People List Page");ga("customTracker0.set", "dimension4", "Thu, 03\/11\/2021 - 10:22");ga("send", "pageview");ga("customTracker0.send", "pageview");
# //--><!]]>
# </script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/js/ucb.js?rm4bdq"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/program\/data-science\/","pathPrefix":"","setHasJsCookie":0,"ajaxPageState":{"theme":"cumodern","theme_token":"vlsi3D_zP2NsxSLcY-m7LmTgtrr0IyvQChmI_bsF-NM","js":{"profiles\/express\/modules\/custom\/backstretch\/bs.js":1,"profiles\/express\/modules\/features\/cu_search\/js\/cu-search.js":1,"profiles\/express\/themes\/ucb\/js\/track-focus.js":1,"0":1,"profiles\/express\/modules\/custom\/cu_back_to_top\/cu_back_to_top.js":1,"public:\/\/google_tag\/google_tag.script.js":1,"profiles\/express\/libraries\/modernizr\/modernizr.min.js":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/jquery\/1.9\/jquery.min.js":1,"1":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/jquery-migrate\/1\/jquery-migrate.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"profiles\/express\/libraries\/fitvids\/jquery.fitvids.js":1,"profiles\/express\/libraries\/match-height\/jquery.matchHeight-min.js":1,"profiles\/express\/libraries\/waypoints\/waypoint.js":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.core.min.js":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.widget.min.js":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.accordion.min.js":1,"profiles\/express\/modules\/features\/cu_colorbox\/js\/cu-colorbox.js":1,"profiles\/express\/modules\/custom\/cu_expandable\/js\/expandable.plugin.js":1,"profiles\/express\/modules\/custom\/cu_expandable\/js\/cu-expandable.js":1,"profiles\/express\/modules\/custom\/cu_share\/js\/cu_share.js":1,"profiles\/express\/modules\/custom\/cu_video_hero_unit_bundle\/js\/cu-video-hero.js":1,"profiles\/express\/modules\/custom\/express_collections_bundle\/js\/express-collections-bundle.js":1,"profiles\/express\/modules\/custom\/express_layout\/js\/express-layout.js":1,"profiles\/express\/modules\/contrib\/fitvids\/fitvids.js":1,"profiles\/express\/modules\/contrib\/google_cse\/google_cse.js":1,"profiles\/express\/modules\/custom\/site_navigation_menus\/js\/site-navigation-menus.js":1,"profiles\/express\/libraries\/colorbox\/jquery.colorbox-min.js":1,"profiles\/express\/modules\/contrib\/colorbox\/js\/colorbox.js":1,"profiles\/express\/modules\/contrib\/colorbox\/styles\/stockholmsyndrome\/colorbox_style.js":1,"profiles\/express\/modules\/contrib\/context_accordion\/context_accordion.js":1,"profiles\/express\/libraries\/flickity\/js\/flickity.pkgd.min.js":1,"profiles\/express\/modules\/features\/cu_article\/modules\/cu_article_slider\/js\/cu-article-slider.js":1,"profiles\/express\/modules\/contrib\/files_undo_remove\/files_undo_remove.js":1,"profiles\/express\/libraries\/backstretch\/jquery.backstretch.js":1,"profiles\/express\/modules\/contrib\/rave_alerts\/js\/rave_alerts.js":1,"profiles\/express\/modules\/features\/cu_block_section\/js\/cu-block-section.js":1,"profiles\/express\/modules\/features\/cu_block_section\/js\/parallaxie.js":1,"profiles\/express\/modules\/custom\/cu_shortcodes\/js\/cu_shortcodes.js":1,"profiles\/express\/modules\/custom\/cu_shortcodes\/js\/counter.js":1,"\/\/www.youtube.com\/iframe_api":1,"profiles\/express\/modules\/contrib\/google_analytics\/googleanalytics.js":1,"2":1,"profiles\/express\/themes\/ucb\/js\/ucb.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.accordion.css":1,"profiles\/express\/modules\/features\/cu_article\/modules\/cu_article_slider\/css\/cu-article-slider.css":1,"profiles\/express\/modules\/custom\/cu_campus_news_bundle\/cu_campus_news\/css\/cu-campus-news.css":1,"profiles\/express\/modules\/custom\/cu_dashboard_seo\/css\/cu-dashboard-seo.css":1,"profiles\/express\/modules\/custom\/cu_expandable\/css\/cu-expandable.css ...
# //--><!]]>
# </script>
#       <!--[if lt IE 9]>
#     <script src="/program/data-science/profiles/express/themes/ucb/js/html5-respond.js"></script>
#     <![endif]-->
#   </head>
# <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-169 node-type-people-list-page layout-default headings-bold page-title-image-background-transparent layout-responsive max-width-1200 primary-sidebar-second express-site-type- banner-black layout-wide" >
#       <p id="skip-link">
#       <a href="#main" class="element-invisible element-focusable">Skip to Content</a>
#     </p>
#     <noscript aria-hidden="true"><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-M3DX2QP" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>  <div class="page-wrapper">
#   <div class="page page node-published">
#     <!-- ALERTS -->
#           <div id="alerts-wide-wrapper" class="section">
#         <div id="alerts" class="clearfix">
#             <div class="region region-alerts">
#     <div id="block-rave-alerts-rave-alerts" class="block block-rave-alerts  block-rave-alerts-rave-alerts">
#   <div class="block-inner-wrapper block-inner clearfix">
#                 <div class="content">
#       <div id="rave-alerts" data-remote-url="">
#   </div>
#     </div>
#   </div>
# </div>
#   </div>
#         </div>
#       </div>
#
#     <!-- CAMPUS BRANDING -->
#     <div class="brand-bar brand-bar-color-black no-underline">
#   <div class="container">
#     <div class="brand-bar-container">
#       <div class="brand-logo">
#         <a href="http://www.colorado.edu"><img src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/images/cu-boulder-logo-text-black.svg" alt="University of Colorado Boulder" /></a>
#       </div>
#       <div class="brand-links">
#       </div>
#       <div class="search-toggle-wrapper">
#         <a href="https://www.colorado.edu/search" id="search-toggle" class="search-toggle" aria-haspopup="true" aria-expanded="false" aria-controls="search" aria-label="Search"><i class="fa fa-search fa-fw"></i><span class="element-invisible">Search </span></a>
#       </div>
#     </div>
#   </div>
# </div>
#     <!-- /CAMPUS BRANDING -->
#
#     <!-- DESKTOP SEARCH -->
#     <div id="search" tabindex="-1" class="background-black">
#       <div id="search-inner">
#         <div class="container container-small">
#           <div class="search-form">
#
#               <div class="cu-search-box cu-search-box-small animated" role="search">
#     <h2>Search</h2>
#     <form class="cu-search-form" action="https://www.colorado.edu/search" method="get">
#       <div class="search-form-wrapper">
#         <div class="search-fields">
#           <div class="cu-search">
#             <div class="form-item form-type-textfield form-item-search-keys">
#               <label class="element-invisible" for="edit-search-keys">Enter the terms you wish to search for. </label>
#               <input placeholder="Search Colorado.edu" type="search" id="edit-search-keys" name="cse" value="" size="15" maxlength="1024" class="form-text">
#             </div>
#             <div class="form-actions form-wrapper" id="edit-actions"><input type="submit" id="edit-submit" name="op" value="Search" class="form-submit"></div>
#           </div>
#         </div>
#
#                         <div class="campus-links">
#           <h3 class="display-inline">Other ways to search: </h3>
#           <ul class="inline inline-menu">
#             <li><a href="https://calendar.colorado.edu">Events Calendar</a></li>
#             <li><a href="https://www.colorado.edu/map">Campus Map</a></li>
#           </ul>
#
#         </div>
#             </div>
#     </form>
#   </div>
#             <button id="close-search"><i class="fa fa-times" aria-hidden="true"></i><span class="element-invisible">Close</span></button>
#           </div>
#         </div>
#       </div>
#     </div>
#     <!-- /DESKTOP SEARCH -->
#
#     <!-- SITE HEADER -->
#     <div id="header-wrapper" class="section header-wrapper no-underline cu-header">
#       <div class="container">
#       <header class="ucb header clearfix" id="header" role="banner" tabindex="-1">
#         <div class="site-name-wrapper">
#
#
#       <div class="site-name">
#       <a href="/program/data-science/" title="Home" class="header__site-link" rel="home"><span>Master of Science in Data Science</span></a>
#     </div>
#
# <div id="print-site-name">Master of Science in Data Science</div>
#
#         </div>
#         <div class="mobile-menu-toggle menu-toggle">
#           <button id="toggle" aria-haspopup="true" aria-expanded="false" aria-controls="mobile-menu" aria-label="Navigation"><i class="fa fa-reorder fa-fw" aria-hidden="true"></i><span class="mobile-menu-text">Menu </span></button>
#         </div>
#       </header>
#     </div>
#     </div>
#     <!-- /SITE HEADER -->
#
#     <!-- NAVIGATION -->
#     <div id="navigation-wrapper" class="navigation-wrapper section no-underline">
#
#       <!-- Main menu -->
#       <div id="main-menu-wrapper" class="section">
#         <div id="navigation" class="container">
#           <div class="nav-inner clearfix">
#               <nav role="navigation" tabindex="-1" class="region region-menu">
#
#     <div>
#       <h2 class="element-invisible">Main menu</h2>  <ul class="links inline clearfix" id="main-menu"><li class="home-link first"><a href="/program/data-science/" id="home-link" class="home-link first"><i class="fa fa-home"></i><span class="element-invisible">Home</span></a></li><li class=""><a href="/program/data-science/big-opportunities-in-big-data-Landing-Page">Academics</a></li><li class=""><a href="/program/data-science/campus-overview">On Campus</a></li><li class=""><a href="/program/data-science/coursera-overview">Online</a></li><li class="active-trail"><a href="/program/data-science/faculty" class="active-trail active">Our People</a></li><li class=""><a href="/program/data-science/about">About</a></li><li class="last"><a href="/program/data-science/student-jobs" class="last">Student Jobs</a></li>  </ul>    </div>
#
#
#   </nav>
#           </div>
#         </div>
#       </div>
#       <!-- /Main menu -->
#
#       <!-- Secondary menu under main menu -->
#                     <div id="secondary-menu-wrapper" class="section">
#           <div id="secondary-navigation" class="container">
#             <div class="secondary-nav-inner clearfix">
#                 <nav class="header__secondary-menu" id="secondary-menu" role="navigation">
#     <h2 class="element-invisible">Secondary Menu</h2>  <ul class="links inline clearfix"><li class="first"><a href="/program/data-science/employers" class="first">For Employers</a></li><li class=""><a href="/program/data-science/graduation-information">Graduation Information</a></li><li class="last"><a href="/program/data-science/news" class="last">News and Events</a></li>  </ul>  </nav>
#             </div>
#           </div>
#         </div>
#         <!-- /Secondary menu under main menu -->
#           </div>
#     <!-- /NAVIGATION -->
#
#     <!-- MOBILE NAVIGATION -->
#     <div id="mobile-navigation-wrapper" class="section no-underline">
#       <div id="mobile-navigation">
#         <!-- Mobile search -->
#         <div id="mobile-search">
#                   </div>
#         <!-- Mobile menu -->
#         <nav id="mobile-menu" role="navigation">
#                   <h2 class="element-invisible">Mobile menu</h2><ul id="main-menu-mobile" class="links clearfix"><li class="menu-701 first"><a href="/program/data-science/">Home</a></li>
# <li class="menu-2607"><a href="/program/data-science/big-opportunities-in-big-data-Landing-Page">Academics</a></li>
# <li class="menu-1561"><a href="/program/data-science/campus-overview">On Campus</a></li>
# <li class="menu-1449"><a href="/program/data-science/coursera-overview">Online</a></li>
# <li class="menu-2365 active-trail active"><a href="/program/data-science/faculty" class="active-trail active">Our People</a></li>
# <li class="menu-2301"><a href="/program/data-science/about">About</a></li>
# <li class="menu-2743 last"><a href="/program/data-science/student-jobs">Student Jobs</a></li>
# </ul>          <ul id="secondary-menu-mobile" class="links clearfix"><li class="menu-2581 first"><a href="/program/data-science/employers">For Employers</a></li>
# <li class="menu-2770"><a href="/program/data-science/graduation-information">Graduation Information</a></li>
# <li class="menu-2751 last"><a href="/program/data-science/news">News and Events</a></li>
# </ul>                                                </nav>
#       </div>
#     </div>
#     <!-- MOBILE NAVIGATION -->
#
#
#     <!-- MESSAGES/TABS/HELP/ACTION LINKS -->
#     <div class="express-messages section">
#       <div class="container">
#
#
#
#               </div>
#     </div>
#     <!-- /MESSAGES/TABS/HELP/ACTION LINKS -->
#
#     <!-- PAGE CONTENT -->
#     <div class="page-content">
#       <!-- INTRO -->
#             <!-- //INTRO -->
#
#       <!-- SLIDER -->
#             <!-- //SLIDER -->
#
#       <!-- PAGE TITLE IMAGE -->
#             <!-- //PAGE TITLE IMAGE -->
#
#       <!-- MAIN CONTENT -->
#       <div id="main-content-wrapper" class="section main-content-wrapper">
#         <div id="main" class="clearfix">
#                     <div class="container">
#             <!-- TITLE -->
#             <div class="main-title-wrapper ">
#
#               <a id="main-content"></a>
#                                             <h1 class="page-title title " id="page-title">
#                   Our People                </h1>
#                                         </div>
#           </div>
#
#           <!-- POST TITLE WIDE -->
#
#           <!-- POST TITLE -->
#
#           <!-- NODE CONTENT -->
#           <div class="content-wrapper section">
#             <div class="container">
#               <div class="row">
#                 <div id="content" class="col-lg-12 col-md-12 col-sm-12 col-xs-12" role="main">
#                     <div class="region region-content">
#     <div class="cu-share-inline-mobile block"><ul class="soc social-links-24"><li>
#   <span class="social-share-links-text"><i class="fa fa-share-alt"></i> Share </li></span></ul></div><div>
#       <div>
#
#   <div class="field field-name-body field-type-text-with-summary field-label-hidden">
#     <h2>The MS-DS is a truly interdisciplinary program, with faculty in Computer Science, Applied Mathematics, Information Science, and more.</h2>
# <p>Data science faculty members are housed in Applied Mathematics, Computer Science, Information Science, and other departments across campus.</p>
# <p> </p>
# <p> </p>
#   </div>
# <div class="people-list-filter"><form action="/program/data-science/faculty" method="post" id="people-content-type-list-filter-form" accept-charset="UTF-8"><div><div class="form-item form-type-select form-item-person-type">
#   <select id="edit-person-type" name="person_type" class="form-select"><option value="0">All</option><option value="75"> Course Facilitator</option><option value="39"> Faculty</option><option value="73"> Interdisciplinary Leadership</option><option value="78"> Lead Course Facilitator</option><option value="74"> Lecturer</option><option value="27"> Program Leadership</option><option value="81"> Program Management</option><option value="79"> Student Assistant</option></select>
# </div>
# <input type="submit" id="edit-submit" name="op" value="Filter" class="form-submit" /><input type="hidden" name="form_build_id" value="form-2vJkWFuVnUJJF3_BHpl_DSa-JR3KxNk8ETutTvP1nSs" />
# <input type="hidden" name="form_id" value="people_content_type_list_filter_form" />
# <div class="url-textfield"><div class="form-item form-type-textfield form-item-url">
#   <label for="edit-url">Leave this field blank </label>
#  <input autocomplete="off" type="text" id="edit-url" name="url" value="" size="20" maxlength="128" class="form-text" />
# </div>
# </div></div></form></div><h2 class="people-list-group-title people-list-grid-group-title">Program Leadership</h2><div class="people-list-wrapper-grid"><a name="jane+wall" id="jane+wall"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/jane-wall"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/jane_wall.jpg?itok=wscxVVNs" width="600" height="600" alt="Jane Wall" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/jane-wall">Jane Wall</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Faculty Director</div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Interdisciplinary Leadership</h2><div class="people-list-wrapper-grid"><a name="bobby+schnabel" id="bobby+schnabel"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/bobby-schnabel"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/bobby_schnabel.png?itok=Ux77fo71" width="600" height="600" alt="Bobby Schnabel" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/bobby-schnabel">Bobby Schnabel</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Department External Chair &bull; Professor</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="brian+zaharatos" id="brian+zaharatos"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/brian-zaharatos"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/brian_zaharatos_0_copy.jpg?itok=h-VwlXX5" width="600" height="600" alt="Brian Zaharatos" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/brian-zaharatos">Brian Zaharatos</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Director of the Professional Master’s Degree &bull; Senior Instructor</div>
#       <div class="person-departments-grid">Applied Mathematics</div>
#     </div>
#   </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Program Management</h2><div class="people-list-wrapper-grid"><a name="nick+dokkin" id="nick+dokkin"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/nick-dokkin"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/picture3.jpg?itok=IDTTiDrg" width="600" height="600" alt="Photo of Nick" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/nick-dokkin">Nick Dokkin</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Residential Graduate Advisor</div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="josh+kawinski" id="josh+kawinski"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/josh-kawinski"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/jkawinski.png?itok=EwckVYWc" width="600" height="600" alt="Photo of Josh" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/josh-kawinski">Josh Kawinski</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Program and Marketing Coordinator</div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="mika+puseman" id="mika+puseman"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/mika-puseman"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/mika_photo.png?itok=3JFVdrRZ" width="600" height="600" alt="Photo of Mika" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/mika-puseman">Mika Puseman</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid"> Coursera Course Coordinator</div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="kaitlyn+rye" id="kaitlyn+rye"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/kaitlyn-rye"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/rye_headshot_k_rye_.jpg?itok=XX1ByXmU" width="600" height="600" alt="Photo of Kaitlyn" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/kaitlyn-rye">Kaitlyn Rye</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Coursera Graduate Program Advisor </div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Faculty</h2><div class="people-list-wrapper-grid"><a name="jem+corcoran" id="jem+corcoran"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/jem-corcoran"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/jem_corcoran.jpg?itok=PqOlniku" width="600" height="600" alt="Jem Corcoran" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/jem-corcoran">Jem Corcoran</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Associate Professor</div>
#       <div class="person-departments-grid">Applied Mathematics</div>
#     </div>
#   </div>
# </div>
# <a name="anne+dougherty" id="anne+dougherty"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/anne-dougherty"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/anne_d_copy_copy.jpg?itok=683svKUP" width="600" height="600" alt="Anne Dougherty" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/anne-dougherty">Anne Dougherty</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Senior Instructor & University of Colorado Teaching Professor &bull; Associate Department Chair   &bull; Undergraduate Studies Chair </div>
#       <div class="person-departments-grid">Applied Mathematics</div>
#     </div>
#   </div>
# </div>
# <a name="ioana+fleming" id="ioana+fleming"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/ioana-fleming"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/ioana_fleming_copy.jpg?itok=yYkf40ZW" width="600" height="600" alt="Ioana Fleming" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/ioana-fleming">Ioana Fleming</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Senior Instructor &bull; Chair of Undergraduate Education</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="ami+gates" id="ami+gates"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/ami-gates"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/gates_ami_small.jpeg?itok=0JcHLoOA" width="600" height="600" alt="Ami Gates Photo" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/ami-gates">Ami Gates</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Teaching Professor</div>
#       <div class="person-departments-grid">Applied Mathematics &bull; Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="abel+iyasele" id="abel+iyasele"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
# ...
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Student Assistant</div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="lauren+walters" id="lauren+walters"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/lauren-walters"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/screen_shot_2022_09_23_at_12.07.28_pm.png?itok=SZrSbECU" width="600" height="600" alt="Photo of Lauren " /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/lauren-walters">Lauren Walters</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Student Assistant</div>
#       <div class="person-departments-grid">Environmental design</div>
#     </div>
#   </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Lead Course Facilitator</h2><div class="people-list-wrapper-grid"><a name="sanjeev+sanjeev" id="sanjeev+sanjeev"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/sanjeev-sanjeev"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/skfukxc_t1kn7isqvp9sja_5a50b47e50fb47b4b3006aa3b90c39f1_sanjeev_head_shot.jpg?itok=mzw_t0K5" width="600" height="600" alt="Photo of Sanjeev " /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/sanjeev-sanjeev">Sanjeev Sanjeev</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Lead Course Facilitator</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Course Facilitator</h2><div class="people-list-wrapper-grid"><a name="sana+fathima" id="sana+fathima"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/sana-fathima"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/sana_headshot.jpg?itok=_rBdaZZu" width="600" height="600" alt="Photo of Sana" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/sana-fathima">Sana Fathima</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="suraj+greenlund" id="suraj+greenlund"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/suraj-greenlund"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/1653777261900.jpg?itok=_1j9eNa2" width="600" height="600" alt="Photo of Suraj" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/suraj-greenlund">Suraj Greenlund</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="mattison+hineline" id="mattison+hineline"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/mattison-hineline"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/img_20220131_171545.jpg?itok=utc6wNnz" width="600" height="600" alt="Photo of Mattison " /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/mattison-hineline">Mattison Hineline</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="rakshith+jayanna" id="rakshith+jayanna"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/rakshith-jayanna"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/rakshith_photo.jpg?itok=jJ7hYrXY" width="600" height="600" alt="photo of Rakshith" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/rakshith-jayanna">Rakshith Jayanna</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid"></div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="adithiyya+kishoore" id="adithiyya+kishoore"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/adithiyya-kishoore"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/addzy.jpeg?itok=RQToYLuX" width="600" height="600" alt="Photo of Adithiyya" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/adithiyya-kishoore">Adithiyya Kishoore</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="ruijiang+ma" id="ruijiang+ma"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/ruijiang-ma"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/img_6213.png?itok=fUNIKmVS" width="600" height="600" alt="Photo of Ruijiang" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/ruijiang-ma">Ruijiang Ma</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="neeraj+madisetty" id="neeraj+madisetty"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/neeraj-madisetty"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/194469758_4168392816551791_111231886770383538_n.jpg?itok=CGtkFQXe" width="600" height="600" alt="Photo of Neeraj" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/neeraj-madisetty">Neeraj Madisetty</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="ayush+pandey" id="ayush+pandey"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/ayush-pandey"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/ayush_pandey_photograph.jpg?itok=pw6DTrFJ" width="600" height="600" alt="Photo of ayush" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/ayush-pandey">Ayush Pandey</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="pranjal+pathak" id="pranjal+pathak"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/pranjal-pathak"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/5.8._white_passport.jpg?itok=0Lfgmk0Q" width="600" height="600" alt="Photo of Pranjal" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/pranjal-pathak">Pranjal Pathak</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="denis+polgul" id="denis+polgul"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/denis-polgul"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/screen_shot_2022-10-24_at_9.55.00_am.png?itok=Tmx0ax2V" width="600" height="600" alt="Photo of Denis" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/denis-polgul">Denis Polgul</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid"></div>
#       <div class="person-departments-grid">Data Science</div>
#     </div>
#   </div>
# </div>
# <a name="maaz+shaikh" id="maaz+shaikh"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/maaz-shaikh"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/2a600805_23ab_48f5_9613_984820609691.jpg?itok=MUi_uyWh" width="600" height="600" alt="Photo of Maaz" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/maaz-shaikh">Maaz Shaikh</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# <a name="bofan+zheng" id="bofan+zheng"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#
#   <a href="/program/data-science/bofan-zheng"><img class="image-large_square_thumbnail" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/bofan_photo.jpeg?itok=sNICvfbF" width="600" height="600" alt="Photo of Bofan Zheng" /></a>    <div class="person-grid-content-wrapper">
#     <strong><a href="/program/data-science/bofan-zheng">Bofan Zheng</a></strong>
#     <div class="person-view-mode-grid-content">
#       <div class="person-job-titles-grid">Course Facilitator</div>
#       <div class="person-departments-grid">Computer Science</div>
#     </div>
#   </div>
# </div>
# </div>  </div>
# </div>
#   </div>
#                 </div>
#
#                                 <!-- SIDEBARS -->
#                                 <!-- /SIDEBARS -->
#
#               </div>
#             </div>
#           </div>
#
#         </div>
#
#       </div>
#       <!-- /MAIN CONTENT -->
#
#       <!-- FEATURE LAYOUT CONTENT -->
#             <!-- /FEATURE LAYOUT CONTENT -->
#     </div>
#     <!-- /PAGE CONTENT -->
#
#     <!-- POST WIDE -->
#         <!-- /POST WIDE -->
#
#     <!-- AFTER CONTENT -->
#         <!-- /AFTER CONTENT -->
#
#     <!-- AFTER CONTENT2 -->
#         <!-- /AFTER CONTENT2 -->
#
#     <!-- FOOTER SECTION -->
#     <div id="footer-section" class="footer-section background-gray-dark">
#       <!-- FOOTER -->
#             <!-- /FOOTER -->
#
#       <!-- FOOTER MENU -->
#             <!-- /FOOTER MENU -->
#
#       <!-- SITE INFO -->
#       <div id="site-info-wrapper" class="section site-info-wrapper background-black">
#         <div id="site-info" class="site-info">
#           <div class="container">
#
#   <footer id="site-footer" class="row region region-site-info footer-2col">
#           <div id="site-footer-content" class="col-lg-8 col-md-8">
#         <div id="block-cu-site-info-site-info" class="block block-cu-site-info has-block-title block-cu-site-info-site-info">
#   <div class="block-inner-wrapper block-inner clearfix">
#               <h2 class="block-title"><a href="/program/data-science/">Master of Science in Data Science</a></h2>
#             <div class="content">
#       <p>Offered through an interdisciplinary partnership, data science at CU Boulder is<br />
# 	delivered by the Departments of Applied Mathematics, Computer Science,<br />
# 	and Information Science and awarded by the <a href="https://www.colorado.edu/graduateschool/">Graduate School</a>.</p>
# <p><a href="mailto:datascience@colorado.edu">datascience@colorado.edu</a><br />
# 	303-735-4114 (Monday - Friday 8:30 AM - 5:00 PM MST)</p>
# <p><a href="https://www.linkedin.com/company/cu-boulder-data-science/?viewAsMember=true" class="button button-regular button-gold"><i class="fa fa-linkedin"></i> </a> <a href="https://instagram.com/cuboulderdatascience?igshid=NzNkNDdiOGI=" class="button button-regular button-gold"><i class="fa fa-instagram"></i> </a> <a href="https://www.youtube.com/channel/UCaUZ1BJM35vPZORTLx5wbSQ" class="button button-regular button-gold"><i class="fa fa-youtube"></i> </a></p>
#     </div>
#   </div>
# </div>
#       </div>
#             <div id="cu-footer" class="col-lg-4 col-md-4">
#         <p><a href="//www.colorado.edu"><img src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/images/beboulder/be-boulder-white.svg" alt="University of Colorado Boulder" class="beboulder"/></a></p>
#                 <p><strong><a href="http://www.colorado.edu" class="cu-boulder-homepage-link">University of Colorado Boulder</a></strong><br />&copy; Regents of the University of Colorado<br />
#         <span class="required-links"><a href="http://www.colorado.edu/about/privacy-statement">Privacy</a> &bull; <a href="http://www.colorado.edu/about/legal-trademarks">Legal &amp; Trademarks</a> &bull; <a href="http://www.colorado.edu/map">Campus Map</a></span></p>
#     </div>
#   </footer>
#           </div>
#         </div>
#       </div>
#       <!-- /SITE INFO -->
#     </div>
#
#   </div>
# </div>
#   <div class="cu-share-sidebar"><ul class="soc social-links-48"></ul></div><div id="cu_back_to_top"><a href="#page" title="Back to Top">Return to the top of the page</a></div><script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/backstretch/bs.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_search/js/cu-search.js?rm4bdq"></script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/js/track-focus.js?rm4bdq"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery(document).ready(function () { if (!Modernizr.svgasimg) {
#   jQuery("img#logo").attr("src", "https://www.colorado.edu/program/data-science/profiles/express/themes/cumodern/logo.png");} });
# //--><!]]>
# </script>
# <script type="text/javascript" src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_back_to_top/cu_back_to_top.js?rm4bdq"></script>
# </body>
# </html>

# %% [markdown]
# I have the complete HTML data of the faculty website for CU Boulder Data Science.

# %% [markdown]
# print(website) prints the status of the response & print(website.data) prints the HTML data.

# %% [markdown]
# ### Title of the Page

# %%
soup = BeautifulSoup(website.text, 'html.parser')
print(soup.title)
# Out:
# <title>Our People | Master of Science in Data Science | University of Colorado Boulder</title>

# %% [markdown]
# ### Get all URL's

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #main
# http://www.colorado.edu
# https://www.colorado.edu/search
# https://calendar.colorado.edu
# https://www.colorado.edu/map
# /program/data-science/
# /program/data-science/
# /program/data-science/big-opportunities-in-big-data-Landing-Page
# /program/data-science/campus-overview
# /program/data-science/coursera-overview
# /program/data-science/faculty
# /program/data-science/about
# /program/data-science/student-jobs
# /program/data-science/employers
# /program/data-science/graduation-information
# /program/data-science/news
# /program/data-science/
# /program/data-science/big-opportunities-in-big-data-Landing-Page
# /program/data-science/campus-overview
# /program/data-science/coursera-overview
# /program/data-science/faculty
# /program/data-science/about
# /program/data-science/student-jobs
# /program/data-science/employers
# /program/data-science/graduation-information
# /program/data-science/news
# None
# None
# /program/data-science/jane-wall
# /program/data-science/jane-wall
# None
# /program/data-science/bobby-schnabel
# /program/data-science/bobby-schnabel
# None
# /program/data-science/brian-zaharatos
# /program/data-science/brian-zaharatos
# None
# /program/data-science/nick-dokkin
# /program/data-science/nick-dokkin
# None
# /program/data-science/josh-kawinski
# /program/data-science/josh-kawinski
# None
# /program/data-science/mika-puseman
# /program/data-science/mika-puseman
# None
# /program/data-science/kaitlyn-rye
# /program/data-science/kaitlyn-rye
# None
# /program/data-science/jem-corcoran
# /program/data-science/jem-corcoran
# None
# /program/data-science/anne-dougherty
# /program/data-science/anne-dougherty
# None
# /program/data-science/ioana-fleming
# /program/data-science/ioana-fleming
# None
# /program/data-science/ami-gates
# /program/data-science/ami-gates
# None
# /program/data-science/abel-iyasele-0
# /program/data-science/abel-iyasele-0
# None
# /program/data-science/geena-kim
# /program/data-science/geena-kim
# None
# /program/data-science/william-kuskin
# /program/data-science/william-kuskin
# None
# /program/data-science/qin-christine-lv
# /program/data-science/qin-christine-lv
# None
# /program/data-science/osita-onyejekwe
# /program/data-science/osita-onyejekwe
# None
# /program/data-science/alan-paradise
# /program/data-science/alan-paradise
# None
# /program/data-science/al-pisano
# /program/data-science/al-pisano
# None
# /program/data-science/sriram-sankaranarayanan
# /program/data-science/sriram-sankaranarayanan
# None
# /program/data-science/chris-vargo
# /program/data-science/chris-vargo
# None
# /program/data-science/di-wu
# /program/data-science/di-wu
# None
# /program/data-science/dave-underwood
# /program/data-science/dave-underwood
# None
# /program/data-science/swapnil-sethi
# /program/data-science/swapnil-sethi
# None
# /program/data-science/darsh-shah
# /program/data-science/darsh-shah
# None
# /program/data-science/lauren-walters
# /program/data-science/lauren-walters
# None
# /program/data-science/sanjeev-sanjeev
# /program/data-science/sanjeev-sanjeev
# None
# /program/data-science/sana-fathima
# /program/data-science/sana-fathima
# None
# /program/data-science/suraj-greenlund
# /program/data-science/suraj-greenlund
# None
# /program/data-science/mattison-hineline
# /program/data-science/mattison-hineline
# None
# /program/data-science/rakshith-jayanna
# /program/data-science/rakshith-jayanna
# None
# /program/data-science/adithiyya-kishoore
# /program/data-science/adithiyya-kishoore
# None
# /program/data-science/ruijiang-ma
# /program/data-science/ruijiang-ma
# None
# /program/data-science/neeraj-madisetty
# /program/data-science/neeraj-madisetty
# None
# /program/data-science/ayush-pandey
# /program/data-science/ayush-pandey
# None
# /program/data-science/pranjal-pathak
# /program/data-science/pranjal-pathak
# None
# /program/data-science/denis-polgul
# /program/data-science/denis-polgul
# None
# /program/data-science/maaz-shaikh
# /program/data-science/maaz-shaikh
# None
# /program/data-science/bofan-zheng
# /program/data-science/bofan-zheng
# /program/data-science/
# https://www.colorado.edu/graduateschool/
# mailto:datascience@colorado.edu
# https://www.linkedin.com/company/cu-boulder-data-science/?viewAsMember=true
# https://instagram.com/cuboulderdatascience?igshid=NzNkNDdiOGI=
# https://www.youtube.com/channel/UCaUZ1BJM35vPZORTLx5wbSQ
# //www.colorado.edu
# http://www.colorado.edu
# http://www.colorado.edu/about/privacy-statement
# http://www.colorado.edu/about/legal-trademarks
# http://www.colorado.edu/map
# #page

# %% [markdown]
# ### Objects of BeautifulSoup

# %% [markdown]
# So technically what is BeautrifulSoup? Now we know that it is used to scrape data and even have tried to get some data. But how does that work internally? The answer is that the HTML is passed to the BeautifulSoup Constructor which gets converted to objects. The objects are

# %% [markdown]
# - Comments

# %% [markdown]
# - BeautifulSoup

# %% [markdown]
# - Tag

# %% [markdown]
# - NavigableString

# %% [markdown]
# ### BeautifulSoup

# %%
from bs4 import BeautifulSoup

soup=BeautifulSoup(website.text,'html.parser')

print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# The BeautifulSoup object is the complete document which we are trying to scrape.

# %% [markdown]
# ### Tag

# %%
# Import Beautiful Soup
from bs4 import BeautifulSoup
   
# Create dummy HTML page
soup = BeautifulSoup('''
    <html>
        <b>Welcome to Data Mining</b>
    </html>
    ''', "html.parser")
   
# Get the tag
tag = soup.b
   
# Print the output
print(type(tag))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# A tag object is the same as the HTML or XML tags.

# %% [markdown]
# The tag has two features

# %% [markdown]
# Name - It can be accessed with a .name suffix. It will return the type of tag.
# Attributes - A tag object can have  various attributes such as “class”, “href”, “id”, etc

# %%
# Import Beautiful Soup
from bs4 import BeautifulSoup
   
soup = BeautifulSoup('''
    <html>
        <p class="course">Data Mining</p>
    </html>
    ''', "html.parser")
   
# Get the tag
tag = soup.p
 
print(tag["class"])
 
# modifying class
tag["class"] = "lecture"
print(tag)
# Out:
# ['course']
# <p class="lecture">Data Mining</p>

# %% [markdown]
# ### NavigableString Object

# %%
from bs4 import BeautifulSoup

soup=BeautifulSoup('<div>Welcome to Data Mining</div>','html.parser')

print(type(soup.text))
# Out:
# <class 'str'>

# %% [markdown]
# The text within the tags is the String

# %% [markdown]
# ### Comments

# %%
from bs4 import BeautifulSoup

soup=BeautifulSoup('<div><!-- This is the comments section --></div>','html.parser')

print(soup.div)
# Out:
# <div><!-- This is the comments section --></div>

# %% [markdown]
# As the name suggests the object contains all the comments available in the HTML document

# %% [markdown]
# ### Search in a parse tree - find() method

# %% [markdown]
# You can use find() when you know that there is only one element with a particular class ‘x’ then you can use the find() method to find that particular tag.

# %%
from bs4 import BeautifulSoup

soup=BeautifulSoup('<div class="dm">data mining</div><div class="dc">data center</div><div class="ml">machine learning</div>','html.parser')

data = soup.find("div",{"class":"dm"}).text

print(data)
# Out:
# data mining

# %%
from bs4 import BeautifulSoup

soup=BeautifulSoup('<div class="dm">data mining</div><div class="dm">data center</div><div class="ml">machine learning</div>','html.parser')

data = soup.find("div",{"class":"dm"}).text

print(data)
# Out:
# data mining

# %% [markdown]
# Observe that class dm has two elements and the first one is chosen in the 2nd snippet.

# %% [markdown]
# ### Search in a parse tree - find_all() method

# %% [markdown]
# Using the find_all() method you can extract all the elements with a particular tag. Unlike the find() method you can extract data from any tag even if it doesn’t appear first.

# %%
from bs4 import BeautifulSoup

soup=BeautifulSoup('<div class="dm">data mining</div><div class="dm">data center</div><div class="ml">machine learning</div>','html.parser')

data = soup.find_all("div",{"class":"dm"})
print(data)
print(data[1].text)
# Out:
# [<div class="dm">data mining</div>, <div class="dm">data center</div>]
# data center

# %% [markdown]
# ## Sample program to extract data from CU Boulder Data Science faculty website

# %% [markdown]
# Let's perform data extraction on our faculty website and prepare a data frame with names of the faculty and their positions.

# %%
#Get the HTML page
import requests

page = requests.get("https://www.colorado.edu/program/data-science/faculty")
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html dir="ltr" lang="en" xmlns:og="http://ogp.me/ns#"><!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="https://www.colorado.edu/program/data-science/profiles/express/themes/cumodern/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://www.colorado.edu/program/data-science/feed/rss.xml" rel="alternate"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="//fonts.googleapis.com" rel="preconnect"/>
# <meta content="The MS-DS is a truly interdisciplinary program, with faculty in Computer Science, Applied Mathematics, Information Science, and more. Data science faculty members are housed in Applied Mathematics, Computer Science, Information Science, and other departments across campus.    " name="description"/>
# <link crossorigin="" href="//fonts.gstatic.com" rel="preconnect"/>
# <link href="//fonts.googleapis.com/css2?family=Roboto+Condensed:wght@700&amp;family=Roboto:wght@400;700&amp;display=swap" rel="stylesheet" type="text/css"/>
# <meta content="Drupal 7 (https://www.drupal.org)" name="generator"/>
# <link href="https://www.colorado.edu/program/data-science/faculty" rel="canonical"/>
# <link href="https://www.colorado.edu/program/data-science/node/169" rel="shortlink"/>
# <meta content="Master of Science in Data Science" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.colorado.edu/program/data-science/faculty" property="og:url"/>
# <meta content="Our People" property="og:title"/>
# <meta content="The MS-DS is a truly interdisciplinary program, with faculty in Computer Science, Applied Mathematics, Information Science, and more. Data science faculty members are housed in Applied Mathematics, Computer Science, Information Science, and other departments across campus.    " property="og:description"/>
# <meta content="2022-09-23T13:31:12-06:00" property="og:updated_time"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.colorado.edu/program/data-science/faculty" name="twitter:url"/>
# <meta content="Our People" name="twitter:title"/>
# <meta content="The MS-DS is a truly interdisciplinary program, with faculty in Computer Science, Applied Mathematics, Information Science, and more. Data science faculty members are housed in Applied Mathematics," name="twitter:description"/>
# <meta content="2021-03-11T10:22:39-07:00" property="article:published_time"/>
# <meta content="2022-09-23T13:31:12-06:00" property="article:modified_time"/>
# <title>Our People | Master of Science in Data Science | University of Colorado Boulder</title>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="on" http-equiv="cleartype"/>
# <style media="screen" type="text/css">
# @import url("https://www.colorado.edu/program/data-science/modules/system/system.base.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/system/system.menus.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/system/system.messages.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/system/system.theme.css?rm4bdq");
# </style>
# <style media="screen" type="text/css">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/themes/base/minified/jquery.ui.core.min.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/themes/base/minified/jquery.ui.accordion.min.css?rm4bdq");
# </style>
# <style media="screen" type="text/css">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/modules/cu_article_slider/css/cu-article-slider.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_campus_news_bundle/cu_campus_news/css/cu-campus-news.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_dashboard_seo/css/cu-dashboard-seo.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_expandable/css/cu-expandable.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_inactive_users/css/cu-inactive-users.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_js_includes/css/cu-js-includes.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_profile_module_manager/css/cu-profile-module-manager.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/cu_related_articles/css/cu-related-articles.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_rss/css/cu-rss.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_share/css/cu-share.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_wysiwyg/cu-wysiwyg.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/date/date_api/date.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/date/date_popup/themes/datepicker.1.7.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_add_content/css/express-add-content.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_block_designer/css/express-block-designer.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_block_designer/modules/express_block_designer_menu/css/exbd-menu.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_collections_bundle/css/express-collections-bundle.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_layout/css/express-layout-admin.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_localist_bundle/css/express-localist-bundle.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_localist_bundle/css/express-localist-bundle-theme.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/fences/field.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/fitvids/fitvids.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/google_cse/google_cse.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/node/node.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/rave_alerts/css/rave_alerts.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/site_navigation_menus/css/site-navigation-menus.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/modules/user/user.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/video_filter/video_filter.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/views/css/views.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_users/css/cu-users.css?rm4bdq");
# </style>
# <style media="screen" type="text/css">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/colorbox/styles/stockholmsyndrome/colorbox_style.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/context_accordion/context_accordion.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/ctools/css/ctools.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/libraries/flickity/css/flickity.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/libraries/fontawesome/css/font-awesome.min.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/files_undo_remove/files_undo_remove.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/backstretch/backstretch.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_block_row/css/cu-block-row.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_block_section/css/cu-block-section.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_facebook_activity/cu_facebook_activity.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_feature_callout/css/cu_feature_callout.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_feature_callout/css/feature-callout-block-designer.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_give_buttons/styles/give-button.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_hero_unit/css/cu_hero_unit.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_menu_icon/cu_menu_icon.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_publications_bundle/cu_publication/css/cu-publication.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_rss_block/css/cu-rss-block.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_search/css/cu-search.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_shortcodes/css/cu_shortcodes.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_shortcodes/css/cu-shortcodes-columns.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_site_info/site_info.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_social_links/css/social_links.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_twitter_feed/cu_twitter_feed.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_video_hero_unit_bundle/css/cu_video_hero_unit.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_video_reveal/css/cu-video-reveal.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_layout/css/express-layout.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_settings/css/express-settings.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/files/css/files.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/profile_module_manager/css/profile-module-manager.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/css/cu-article.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/css/cu-article-grid.css?rm4bdq");
# </style>
# <style media="screen" type="text/css">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/css/owl.carousel.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_faq/css/cu_faq.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_page/cu-page.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_theme_picker/express_theme_picker.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/people_content_type/css/people_content_type.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/features/photo_gallery/css/photo-gallery.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_back_to_top/cu_back_to_top.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/sites/default/files/honeypot/honeypot.css?rm4bdq");
# </style>
# <style media="screen" type="text/css">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/css/ucb.css?rm4bdq");
# @import url("https://www.colorado.edu/program/data-science/profiles/express/themes/cumodern/css/modern-styles.css?rm4bdq");
# </style>
# <style media="print" type="text/css">
# @import url("https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/css/ucb-print.css?rm4bdq");
# </style>
# <script defer="defer" src="https://www.colorado.edu/program/data-science/sites/default/files/google_tag/google_tag.script.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/libraries/modernizr/modernizr.min.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/jquery/1.9/jquery.min.js?v=1.9.1" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.migrateMute=true;jQuery.migrateTrace=false;
# //--><!]]>
# </script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/jquery-migrate/1/jquery-migrate.min.js?v=1" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/misc/jquery-extend-3.4.0.js?v=1.9.1" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/misc/jquery-html-prefilter-3.5.0-backport.js?v=1.9.1" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/misc/jquery.once.js?v=1.2" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/misc/drupal.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/libraries/fitvids/jquery.fitvids.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/libraries/match-height/jquery.matchHeight-min.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/libraries/waypoints/waypoint.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/ui/minified/jquery.ui.core.min.js?v=1.10.2" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/ui/minified/jquery.ui.widget.min.js?v=1.10.2" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/jquery_update/replace/ui/ui/minified/jquery.ui.accordion.min.js?v=1.10.2" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_colorbox/js/cu-colorbox.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_expandable/js/expandable.plugin.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_expandable/js/cu-expandable.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_share/js/cu_share.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_video_hero_unit_bundle/js/cu-video-hero.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_collections_bundle/js/express-collections-bundle.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/express_layout/js/express-layout.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/fitvids/fitvids.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/google_cse/google_cse.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/site_navigation_menus/js/site-navigation-menus.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/libraries/colorbox/jquery.colorbox-min.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/colorbox/js/colorbox.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/colorbox/styles/stockholmsyndrome/colorbox_style.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/context_accordion/context_accordion.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/libraries/flickity/js/flickity.pkgd.min.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_article/modules/cu_article_slider/js/cu-article-slider.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/files_undo_remove/files_undo_remove.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/libraries/backstretch/jquery.backstretch.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/rave_alerts/js/rave_alerts.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_block_section/js/cu-block-section.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_block_section/js/parallaxie.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_shortcodes/js/cu_shortcodes.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_shortcodes/js/counter.js?rm4bdq" type="text/javascript"></script>
# <script src="//www.youtube.com/iframe_api" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/contrib/google_analytics/googleanalytics.js?rm4bdq" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-105731679-1", {"cookieDomain":"auto"});ga("create", "UA-142322394-2", "auto", {"name":"customTracker0"});ga("set", "anonymizeIp", true);ga("set", "dimension1", "169");ga("set", "dimension2", "Our People");ga("set", "dimension3", "People List Page");ga("set", "dimension4", "Thu, 03\/11\/2021 - 10:22");ga("customTracker0.set", "anonymizeIp", true);ga("customTracker0.set", "dimension1", "169");ga("customTracker0.set", "dimension2", "Our People");ga("customTracker0.set", "dimension3", "People List Page");ga("customTracker0.set", "dimension4", "Thu, 03\/11\/2021 - 10:22");ga("send", "pageview");ga("customTracker0.send", "pageview");
# //--><!]]>
# </script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/js/ucb.js?rm4bdq" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/program\/data-science\/","pathPrefix":"","setHasJsCookie":0,"ajaxPageState":{"theme":"cumodern","theme_token":"CQGMoroVZzu3S3sZDVn_QOHMW1RMZeSKmOYo505LQPI","js":{"profiles\/express\/modules\/custom\/backstretch\/bs.js":1,"profiles\/express\/modules\/features\/cu_search\/js\/cu-search.js":1,"profiles\/express\/themes\/ucb\/js\/track-focus.js":1,"0":1,"profiles\/express\/modules\/custom\/cu_back_to_top\/cu_back_to_top.js":1,"public:\/\/google_tag\/google_tag.script.js":1,"profiles\/express\/libraries\/modernizr\/modernizr.min.js":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/jquery\/1.9\/jquery.min.js":1,"1":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/jquery-migrate\/1\/jquery-migrate.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"profiles\/express\/libraries\/fitvids\/jquery.fitvids.js":1,"profiles\/express\/libraries\/match-height\/jquery.matchHeight-min.js":1,"profiles\/express\/libraries\/waypoints\/waypoint.js":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.core.min.js":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.widget.min.js":1,"profiles\/express\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.accordion.min.js":1,"profiles\/express\/modules\/features\/cu_colorbox\/js\/cu-colorbox.js":1,"profiles\/express\/modules\/custom\/cu_expandable\/js\/expandable.plugin.js":1,"profiles\/express\/modules\/custom\/cu_expandable\/js\/cu-expandable.js":1,"profiles\/express\/modules\/custom\/cu_share\/js\/cu_share.js":1,"profiles\/express\/modules\/custom\/cu_video_hero_unit_bundle\/js\/cu-video-hero.js":1,"profiles\/express\/modules\/custom\/express_collections_bundle\/js\/express-collections-bundle.js":1,"profiles\/express\/modules\/custom\/express_layout\/js\/express-layout.js":1,"profiles\/express\/modules\/contrib\/fitvids\/fitvids.js":1,"profiles\/express\/modules\/contrib\/google_cse\/google_cse.js":1,"profiles\/express\/modules\/custom\/site_navigation_menus\/js\/site-navigation-menus.js":1,"profiles\/express\/libraries\/colorbox\/jquery.colorbox-min.js":1,"profiles\/express\/modules\/contrib\/colorbox\/js\/colorbox.js":1,"profiles\/express\/modules\/contrib\/colorbox\/styles\/stockholmsyndrome\/colorbox_style.js":1,"profiles\/express\/modules\/contrib\/context_accordion\/context_accordion.js":1,"profiles\/express\/libraries\/flickity\/js\/flickity.pkgd.min.js":1,"profiles\/express\/modules\/features\/cu_article\/modules\/cu_article_slider\/js\/cu-article-slider.js":1,"profiles\/express\/modules\/contrib\/files_undo_remove\/files_undo_remove.js":1,"profiles\/express\/libraries\/backstretch\/jquery.backstretch.js":1,"profiles\/express\/modules\/contrib\/rave_alerts\/js\/rave_alerts.js":1,"profiles\/express\/modules\/features\/cu_block_section\/js\/cu-block-section.js":1,"profiles\/express\/modules\/features\/cu_block_section\/js\/parallaxie.js":1,"profiles\/express\/modules\/custom\/cu_shortcodes\/js\/cu_shortcodes.js":1,"profiles\/express\/modules\/custom\/cu_shortcodes\/js\/counter.js":1,"\/\/www.youtube.com\/iframe_api":1,"profiles\/express\/modules\/contrib\/google_analytics\/googleanalytics.js":1,"2":1,"profiles\/express\/themes\/ucb\/js\/ucb.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.accordion.css":1,"profiles\/express\/modules\/features\/cu_article\/modules\/cu_article_slider\/css\/cu-article-slider.css":1,"profiles\/express\/modules\/custom\/cu_campus_news_bundle\/cu_campus_news\/css\/cu-campus-news.css":1,"profiles\/express\/modules\/custom\/cu_dashboard_seo\/css\/cu-dashboard-seo.css":1,"profiles\/express\/modules\/custom\/cu_expandable\/css\/cu-expandable.css ...
# //--><!]]>
# </script>
# <!--[if lt IE 9]>
#     <script src="/program/data-science/profiles/express/themes/ucb/js/html5-respond.js"></script>
#     <![endif]-->
# </head>
# <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-169 node-type-people-list-page layout-default headings-bold page-title-image-background-transparent layout-responsive max-width-1200 primary-sidebar-second express-site-type- banner-black layout-wide">
# <p id="skip-link">
# <a class="element-invisible element-focusable" href="#main">Skip to Content</a>
# </p>
# <noscript aria-hidden="true"><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3DX2QP" style="display:none;visibility:hidden" width="0"></iframe></noscript> <div class="page-wrapper">
# <div class="page page node-published">
# <!-- ALERTS -->
# <div class="section" id="alerts-wide-wrapper">
# <div class="clearfix" id="alerts">
# <div class="region region-alerts">
# <div class="block block-rave-alerts block-rave-alerts-rave-alerts" id="block-rave-alerts-rave-alerts">
# <div class="block-inner-wrapper block-inner clearfix">
# <div class="content">
# <div data-remote-url="" id="rave-alerts">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- CAMPUS BRANDING -->
# <div class="brand-bar brand-bar-color-black no-underline">
# <div class="container">
# <div class="brand-bar-container">
# <div class="brand-logo">
# <a href="http://www.colorado.edu"><img alt="University of Colorado Boulder" src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/images/cu-boulder-logo-text-black.svg"/></a>
# </div>
# <div class="brand-links">
# </div>
# <div class="search-toggle-wrapper">
# <a aria-controls="search" aria-expanded="false" aria-haspopup="true" aria-label="Search" class="search-toggle" href="https://www.colorado.edu/search" id="search-toggle"><i class="fa fa-search fa-fw"></i><span class="element-invisible">Search </span></a>
# </div>
# </div>
# </div>
# </div>
# <!-- /CAMPUS BRANDING -->
# <!-- DESKTOP SEARCH -->
# <div class="background-black" id="search" tabindex="-1">
# <div id="search-inner">
# <div class="container container-small">
# <div class="search-form">
# <div class="cu-search-box cu-search-box-small animated" role="search">
# <h2>Search</h2>
# <form action="https://www.colorado.edu/search" class="cu-search-form" method="get">
# <div class="search-form-wrapper">
# <div class="search-fields">
# <div class="cu-search">
# <div class="form-item form-type-textfield form-item-search-keys">
# <label class="element-invisible" for="edit-search-keys">Enter the terms you wish to search for. </label>
# <input class="form-text" id="edit-search-keys" maxlength="1024" name="cse" placeholder="Search Colorado.edu" size="15" type="search" value=""/>
# </div>
# <div class="form-actions form-wrapper" id="edit-actions"><input class="form-submit" id="edit-submit" name="op" type="submit" value="Search"/></div>
# </div>
# </div>
# <div class="campus-links">
# <h3 class="display-inline">Other ways to search: </h3>
# <ul class="inline inline-menu">
# <li><a href="https://calendar.colorado.edu">Events Calendar</a></li>
# <li><a href="https://www.colorado.edu/map">Campus Map</a></li>
# </ul>
# </div>
# </div>
# </form>
# </div>
# <button id="close-search"><i aria-hidden="true" class="fa fa-times"></i><span class="element-invisible">Close</span></button>
# </div>
# </div>
# </div>
# </div>
# <!-- /DESKTOP SEARCH -->
# <!-- SITE HEADER -->
# <div class="section header-wrapper no-underline cu-header" id="header-wrapper">
# <div class="container">
# <header class="ucb header clearfix" id="header" role="banner" tabindex="-1">
# <div class="site-name-wrapper">
# <div class="site-name">
# <a class="header__site-link" href="/program/data-science/" rel="home" title="Home"><span>Master of Science in Data Science</span></a>
# </div>
# <div id="print-site-name">Master of Science in Data Science</div>
# </div>
# <div class="mobile-menu-toggle menu-toggle">
# <button aria-controls="mobile-menu" aria-expanded="false" aria-haspopup="true" aria-label="Navigation" id="toggle"><i aria-hidden="true" class="fa fa-reorder fa-fw"></i><span class="mobile-menu-text">Menu </span></button>
# </div>
# </header>
# </div>
# </div>
# <!-- /SITE HEADER -->
# <!-- NAVIGATION -->
# <div class="navigation-wrapper section no-underline" id="navigation-wrapper">
# <!-- Main menu -->
# <div class="section" id="main-menu-wrapper">
# <div class="container" id="navigation">
# <div class="nav-inner clearfix">
# <nav class="region region-menu" role="navigation" tabindex="-1">
# <div>
# <h2 class="element-invisible">Main menu</h2> <ul class="links inline clearfix" id="main-menu"><li class="home-link first"><a class="home-link first" href="/program/data-science/" id="home-link"><i class="fa fa-home"></i><span class="element-invisible">Home</span></a></li><li class=""><a href="/program/data-science/big-opportunities-in-big-data-Landing-Page">Academics</a></li><li class=""><a href="/program/data-science/campus-overview">On Campus</a></li><li class=""><a href="/program/data-science/coursera-overview">Online</a></li><li class="active-trail"><a class="active-trail active" href="/program/data-science/faculty">Our People</a></li><li class=""><a href="/program/data-science/about">About</a></li><li class="last"><a class="last" href="/program/data-science/student-jobs">Student Jobs</a></li> </ul> </div>
# </nav>
# </div>
# </div>
# </div>
# <!-- /Main menu -->
# <!-- Secondary menu under main menu -->
# <div class="section" id="secondary-menu-wrapper">
# <div class="container" id="secondary-navigation">
# <div class="secondary-nav-inner clearfix">
# <nav class="header__secondary-menu" id="secondary-menu" role="navigation">
# <h2 class="element-invisible">Secondary Menu</h2> <ul class="links inline clearfix"><li class="first"><a class="first" href="/program/data-science/employers">For Employers</a></li><li class=""><a href="/program/data-science/graduation-information">Graduation Information</a></li><li class="last"><a class="last" href="/program/data-science/news">News and Events</a></li> </ul> </nav>
# </div>
# </div>
# </div>
# <!-- /Secondary menu under main menu -->
# </div>
# <!-- /NAVIGATION -->
# <!-- MOBILE NAVIGATION -->
# <div class="section no-underline" id="mobile-navigation-wrapper">
# <div id="mobile-navigation">
# <!-- Mobile search -->
# <div id="mobile-search">
# </div>
# <!-- Mobile menu -->
# <nav id="mobile-menu" role="navigation">
# <h2 class="element-invisible">Mobile menu</h2><ul class="links clearfix" id="main-menu-mobile"><li class="menu-701 first"><a href="/program/data-science/">Home</a></li>
# <li class="menu-2607"><a href="/program/data-science/big-opportunities-in-big-data-Landing-Page">Academics</a></li>
# <li class="menu-1561"><a href="/program/data-science/campus-overview">On Campus</a></li>
# <li class="menu-1449"><a href="/program/data-science/coursera-overview">Online</a></li>
# <li class="menu-2365 active-trail active"><a class="active-trail active" href="/program/data-science/faculty">Our People</a></li>
# <li class="menu-2301"><a href="/program/data-science/about">About</a></li>
# <li class="menu-2743 last"><a href="/program/data-science/student-jobs">Student Jobs</a></li>
# </ul> <ul class="links clearfix" id="secondary-menu-mobile"><li class="menu-2581 first"><a href="/program/data-science/employers">For Employers</a></li>
# <li class="menu-2770"><a href="/program/data-science/graduation-information">Graduation Information</a></li>
# <li class="menu-2751 last"><a href="/program/data-science/news">News and Events</a></li>
# </ul> </nav>
# </div>
# </div>
# <!-- MOBILE NAVIGATION -->
# <!-- MESSAGES/TABS/HELP/ACTION LINKS -->
# <div class="express-messages section">
# <div class="container">
# </div>
# </div>
# <!-- /MESSAGES/TABS/HELP/ACTION LINKS -->
# <!-- PAGE CONTENT -->
# <div class="page-content">
# <!-- INTRO -->
# <!-- //INTRO -->
# <!-- SLIDER -->
# <!-- //SLIDER -->
# <!-- PAGE TITLE IMAGE -->
# <!-- //PAGE TITLE IMAGE -->
# <!-- MAIN CONTENT -->
# <div class="section main-content-wrapper" id="main-content-wrapper">
# <div class="clearfix" id="main">
# <div class="container">
# <!-- TITLE -->
# <div class="main-title-wrapper">
# <a id="main-content"></a>
# <h1 class="page-title title" id="page-title">
#                   Our People                </h1>
# </div>
# </div>
# <!-- POST TITLE WIDE -->
# <!-- POST TITLE -->
# <!-- NODE CONTENT -->
# <div class="content-wrapper section">
# <div class="container">
# <div class="row">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" id="content" role="main">
# <div class="region region-content">
# <div class="cu-share-inline-mobile block"><ul class="soc social-links-24"><li>
# <span class="social-share-links-text"><i class="fa fa-share-alt"></i> Share </span></li></ul></div><div>
# <div>
# <div class="field field-name-body field-type-text-with-summary field-label-hidden">
# <h2>The MS-DS is a truly interdisciplinary program, with faculty in Computer Science, Applied Mathematics, Information Science, and more.</h2>
# <p>Data science faculty members are housed in Applied Mathematics, Computer Science, Information Science, and other departments across campus.</p>
# <p> </p>
# <p> </p>
# </div>
# <div class="people-list-filter"><form accept-charset="UTF-8" action="/program/data-science/faculty" id="people-content-type-list-filter-form" method="post"><div><div class="form-item form-type-select form-item-person-type">
# <select class="form-select" id="edit-person-type" name="person_type"><option value="0">All</option><option value="75"> Course Facilitator</option><option value="39"> Faculty</option><option value="73"> Interdisciplinary Leadership</option><option value="78"> Lead Course Facilitator</option><option value="74"> Lecturer</option><option value="27"> Program Leadership</option><option value="81"> Program Management</option><option value="79"> Student Assistant</option></select>
# </div>
# <input class="form-submit" id="edit-submit" name="op" type="submit" value="Filter"><input name="form_build_id" type="hidden" value="form-5GJwaW21yWdF_brKeWbqF9F57fmu17C8VAeoiUyUCjY">
# <input name="form_id" type="hidden" value="people_content_type_list_filter_form"/>
# <div class="url-textfield"><div class="form-item form-type-textfield form-item-url">
# <label for="edit-url">Leave this field blank </label>
# <input autocomplete="off" class="form-text" id="edit-url" maxlength="128" name="url" size="20" type="text" value=""/>
# </div>
# </div></input></input></div></form></div><h2 class="people-list-group-title people-list-grid-group-title">Program Leadership</h2><div class="people-list-wrapper-grid"><a id="jane+wall" name="jane+wall"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/jane-wall"><img alt="Jane Wall" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/jane_wall.jpg?itok=wscxVVNs" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/jane-wall">Jane Wall</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Faculty Director</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Interdisciplinary Leadership</h2><div class="people-list-wrapper-grid"><a id="bobby+schnabel" name="bobby+schnabel"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/bobby-schnabel"><img alt="Bobby Schnabel" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/bobby_schnabel.png?itok=Ux77fo71" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/bobby-schnabel">Bobby Schnabel</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Department External Chair • Professor</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="brian+zaharatos" name="brian+zaharatos"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/brian-zaharatos"><img alt="Brian Zaharatos" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/brian_zaharatos_0_copy.jpg?itok=h-VwlXX5" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/brian-zaharatos">Brian Zaharatos</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Director of the Professional Master’s Degree • Senior Instructor</div>
# <div class="person-departments-grid">Applied Mathematics</div>
# </div>
# </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Program Management</h2><div class="people-list-wrapper-grid"><a id="nick+dokkin" name="nick+dokkin"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/nick-dokkin"><img alt="Photo of Nick" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/picture3.jpg?itok=IDTTiDrg" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/nick-dokkin">Nick Dokkin</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Residential Graduate Advisor</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="josh+kawinski" name="josh+kawinski"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/josh-kawinski"><img alt="Photo of Josh" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/jkawinski.png?itok=EwckVYWc" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/josh-kawinski">Josh Kawinski</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Program and Marketing Coordinator</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="mika+puseman" name="mika+puseman"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/mika-puseman"><img alt="Photo of Mika" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/mika_photo.png?itok=3JFVdrRZ" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/mika-puseman">Mika Puseman</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid"> Coursera Course Coordinator</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="kaitlyn+rye" name="kaitlyn+rye"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/kaitlyn-rye"><img alt="Photo of Kaitlyn" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/rye_headshot_k_rye_.jpg?itok=XX1ByXmU" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/kaitlyn-rye">Kaitlyn Rye</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Coursera Graduate Program Advisor </div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Faculty</h2><div class="people-list-wrapper-grid"><a id="jem+corcoran" name="jem+corcoran"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/jem-corcoran"><img alt="Jem Corcoran" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/jem_corcoran.jpg?itok=PqOlniku" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/jem-corcoran">Jem Corcoran</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Associate Professor</div>
# <div class="person-departments-grid">Applied Mathematics</div>
# </div>
# </div>
# </div>
# <a id="anne+dougherty" name="anne+dougherty"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/anne-dougherty"><img alt="Anne Dougherty" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/anne_d_copy_copy.jpg?itok=683svKUP" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/anne-dougherty">Anne Dougherty</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Senior Instructor &amp; University of Colorado Teaching Professor • Associate Department Chair   • Undergraduate Studies Chair </div>
# <div class="person-departments-grid">Applied Mathematics</div>
# </div>
# </div>
# </div>
# <a id="ioana+fleming" name="ioana+fleming"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/ioana-fleming"><img alt="Ioana Fleming" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/ioana_fleming_copy.jpg?itok=yYkf40ZW" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/ioana-fleming">Ioana Fleming</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Senior Instructor • Chair of Undergraduate Education</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="ami+gates" name="ami+gates"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/ami-gates"><img alt="Ami Gates Photo" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/gates_ami_small.jpeg?itok=0JcHLoOA" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/ami-gates">Ami Gates</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Teaching Professor</div>
# <div class="person-departments-grid">Applied Mathematics • Data Science</div>
# </div>
# </div>
# </div>
# <a id="abel+iyasele" name="abel+iyasele"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/abel-iyasele-0"><img alt="Abel Iyasele Photo" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/abel_pix_2_-_abel_iyasele_small.jpeg?itok=vuK5Bvvw" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/abel-iyasele-0">Abel Iyasele</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Teaching Assistant Professor</div>
# <div class="person-departments-grid">Information Science • Data Science</div>
# </div>
# </div>
# </div>
# <a id="geena+kim" name="geena+kim"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/geena-kim"><img alt="Geena Kim" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/geena_kim.png?itok=UXUCn7AR" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/geena-kim">Geena Kim</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Post-Baccalaureate Instructor</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="william+kuskin" name="william+kuskin"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/william-kuskin"><img alt="William Kuskin" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/william_kuskin_copy.jpg?itok=A4_t5BiM" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/william-kuskin">William Kuskin</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Professor • CEAS Associate Dean for Digital Education</div>
# <div class="person-departments-grid">English &amp; Engineering</div>
# </div>
# </div>
# </div>
# ...
# <strong><a href="/program/data-science/swapnil-sethi">Swapnil Sethi</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Student Assistant</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="darsh+shah" name="darsh+shah"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/darsh-shah"><img alt="Photo of Darsh " class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/darsh_shah_photo.jpg?itok=OC0VGcJP" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/darsh-shah">Darsh Shah</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Student Assistant</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="lauren+walters" name="lauren+walters"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/lauren-walters"><img alt="Photo of Lauren " class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/screen_shot_2022_09_23_at_12.07.28_pm.png?itok=SZrSbECU" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/lauren-walters">Lauren Walters</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Student Assistant</div>
# <div class="person-departments-grid">Environmental design</div>
# </div>
# </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Lead Course Facilitator</h2><div class="people-list-wrapper-grid"><a id="sanjeev+sanjeev" name="sanjeev+sanjeev"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/sanjeev-sanjeev"><img alt="Photo of Sanjeev " class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/skfukxc_t1kn7isqvp9sja_5a50b47e50fb47b4b3006aa3b90c39f1_sanjeev_head_shot.jpg?itok=mzw_t0K5" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/sanjeev-sanjeev">Sanjeev Sanjeev</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Lead Course Facilitator</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# </div><h2 class="people-list-group-title people-list-grid-group-title">Course Facilitator</h2><div class="people-list-wrapper-grid"><a id="sana+fathima" name="sana+fathima"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/sana-fathima"><img alt="Photo of Sana" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/sana_headshot.jpg?itok=_rBdaZZu" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/sana-fathima">Sana Fathima</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="suraj+greenlund" name="suraj+greenlund"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/suraj-greenlund"><img alt="Photo of Suraj" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/1653777261900.jpg?itok=_1j9eNa2" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/suraj-greenlund">Suraj Greenlund</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="mattison+hineline" name="mattison+hineline"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/mattison-hineline"><img alt="Photo of Mattison " class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/img_20220131_171545.jpg?itok=utc6wNnz" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/mattison-hineline">Mattison Hineline</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="rakshith+jayanna" name="rakshith+jayanna"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/rakshith-jayanna"><img alt="photo of Rakshith" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/rakshith_photo.jpg?itok=jJ7hYrXY" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/rakshith-jayanna">Rakshith Jayanna</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid"></div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="adithiyya+kishoore" name="adithiyya+kishoore"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/adithiyya-kishoore"><img alt="Photo of Adithiyya" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/addzy.jpeg?itok=RQToYLuX" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/adithiyya-kishoore">Adithiyya Kishoore</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="ruijiang+ma" name="ruijiang+ma"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/ruijiang-ma"><img alt="Photo of Ruijiang" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/img_6213.png?itok=fUNIKmVS" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/ruijiang-ma">Ruijiang Ma</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="neeraj+madisetty" name="neeraj+madisetty"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/neeraj-madisetty"><img alt="Photo of Neeraj" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/194469758_4168392816551791_111231886770383538_n.jpg?itok=CGtkFQXe" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/neeraj-madisetty">Neeraj Madisetty</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="ayush+pandey" name="ayush+pandey"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/ayush-pandey"><img alt="Photo of ayush" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/ayush_pandey_photograph.jpg?itok=pw6DTrFJ" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/ayush-pandey">Ayush Pandey</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="pranjal+pathak" name="pranjal+pathak"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/pranjal-pathak"><img alt="Photo of Pranjal" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/5.8._white_passport.jpg?itok=0Lfgmk0Q" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/pranjal-pathak">Pranjal Pathak</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="denis+polgul" name="denis+polgul"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/denis-polgul"><img alt="Photo of Denis" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/screen_shot_2022-10-24_at_9.55.00_am.png?itok=Tmx0ax2V" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/denis-polgul">Denis Polgul</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid"></div>
# <div class="person-departments-grid">Data Science</div>
# </div>
# </div>
# </div>
# <a id="maaz+shaikh" name="maaz+shaikh"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/maaz-shaikh"><img alt="Photo of Maaz" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/2a600805_23ab_48f5_9613_984820609691.jpg?itok=MUi_uyWh" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/maaz-shaikh">Maaz Shaikh</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# <a id="bofan+zheng" name="bofan+zheng"></a><div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
# <a href="/program/data-science/bofan-zheng"><img alt="Photo of Bofan Zheng" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/bofan_photo.jpeg?itok=sNICvfbF" width="600"/></a> <div class="person-grid-content-wrapper">
# <strong><a href="/program/data-science/bofan-zheng">Bofan Zheng</a></strong>
# <div class="person-view-mode-grid-content">
# <div class="person-job-titles-grid">Course Facilitator</div>
# <div class="person-departments-grid">Computer Science</div>
# </div>
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# </div>
# <!-- SIDEBARS -->
# <!-- /SIDEBARS -->
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- /MAIN CONTENT -->
# <!-- FEATURE LAYOUT CONTENT -->
# <!-- /FEATURE LAYOUT CONTENT -->
# </div>
# <!-- /PAGE CONTENT -->
# <!-- POST WIDE -->
# <!-- /POST WIDE -->
# <!-- AFTER CONTENT -->
# <!-- /AFTER CONTENT -->
# <!-- AFTER CONTENT2 -->
# <!-- /AFTER CONTENT2 -->
# <!-- FOOTER SECTION -->
# <div class="footer-section background-gray-dark" id="footer-section">
# <!-- FOOTER -->
# <!-- /FOOTER -->
# <!-- FOOTER MENU -->
# <!-- /FOOTER MENU -->
# <!-- SITE INFO -->
# <div class="section site-info-wrapper background-black" id="site-info-wrapper">
# <div class="site-info" id="site-info">
# <div class="container">
# <footer class="row region region-site-info footer-2col" id="site-footer">
# <div class="col-lg-8 col-md-8" id="site-footer-content">
# <div class="block block-cu-site-info has-block-title block-cu-site-info-site-info" id="block-cu-site-info-site-info">
# <div class="block-inner-wrapper block-inner clearfix">
# <h2 class="block-title"><a href="/program/data-science/">Master of Science in Data Science</a></h2>
# <div class="content">
# <p>Offered through an interdisciplinary partnership, data science at CU Boulder is<br/>
# 	delivered by the Departments of Applied Mathematics, Computer Science,<br/>
# 	and Information Science and awarded by the <a href="https://www.colorado.edu/graduateschool/">Graduate School</a>.</p>
# <p><a href="mailto:datascience@colorado.edu">datascience@colorado.edu</a><br/>
# 	303-735-4114 (Monday - Friday 8:30 AM - 5:00 PM MST)</p>
# <p><a class="button button-regular button-gold" href="https://www.linkedin.com/company/cu-boulder-data-science/?viewAsMember=true"><i class="fa fa-linkedin"></i> </a> <a class="button button-regular button-gold" href="https://instagram.com/cuboulderdatascience?igshid=NzNkNDdiOGI="><i class="fa fa-instagram"></i> </a> <a class="button button-regular button-gold" href="https://www.youtube.com/channel/UCaUZ1BJM35vPZORTLx5wbSQ"><i class="fa fa-youtube"></i> </a></p>
# </div>
# </div>
# </div>
# </div>
# <div class="col-lg-4 col-md-4" id="cu-footer">
# <p><a href="//www.colorado.edu"><img alt="University of Colorado Boulder" class="beboulder" src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/images/beboulder/be-boulder-white.svg"/></a></p>
# <p><strong><a class="cu-boulder-homepage-link" href="http://www.colorado.edu">University of Colorado Boulder</a></strong><br/>© Regents of the University of Colorado<br/>
# <span class="required-links"><a href="http://www.colorado.edu/about/privacy-statement">Privacy</a> • <a href="http://www.colorado.edu/about/legal-trademarks">Legal &amp; Trademarks</a> • <a href="http://www.colorado.edu/map">Campus Map</a></span></p>
# </div>
# </footer>
# </div>
# </div>
# </div>
# <!-- /SITE INFO -->
# </div>
# </div>
# </div>
# <div class="cu-share-sidebar"><ul class="soc social-links-48"></ul></div><div id="cu_back_to_top"><a href="#page" title="Back to Top">Return to the top of the page</a></div><script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/backstretch/bs.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_search/js/cu-search.js?rm4bdq" type="text/javascript"></script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/js/track-focus.js?rm4bdq" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery(document).ready(function () { if (!Modernizr.svgasimg) {
#   jQuery("img#logo").attr("src", "https://www.colorado.edu/program/data-science/profiles/express/themes/cumodern/logo.png");} });
# //--><!]]>
# </script>
# <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_back_to_top/cu_back_to_top.js?rm4bdq" type="text/javascript"></script>
# </body>
# </html>

# %%
# Use prettify to view the DOM structure
print(soup.prettify())
# Out:
#                   <div class="person-job-titles-grid">
#                    Faculty Director
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="people-list-group-title people-list-grid-group-title">
#                Interdisciplinary Leadership
#               </h2>
#               <div class="people-list-wrapper-grid">
#                <a id="bobby+schnabel" name="bobby+schnabel">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/bobby-schnabel">
#                  <img alt="Bobby Schnabel" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/bobby_schnabel.png?itok=Ux77fo71" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/bobby-schnabel">
#                    Bobby Schnabel
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Department External Chair • Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="brian+zaharatos" name="brian+zaharatos">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/brian-zaharatos">
#                  <img alt="Brian Zaharatos" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/brian_zaharatos_0_copy.jpg?itok=h-VwlXX5" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/brian-zaharatos">
#                    Brian Zaharatos
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Director of the Professional Master’s Degree • Senior Instructor
#                   </div>
#                   <div class="person-departments-grid">
#                    Applied Mathematics
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="people-list-group-title people-list-grid-group-title">
#                Program Management
#               </h2>
#               <div class="people-list-wrapper-grid">
#                <a id="nick+dokkin" name="nick+dokkin">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/nick-dokkin">
#                  <img alt="Photo of Nick" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/picture3.jpg?itok=IDTTiDrg" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/nick-dokkin">
#                    Nick Dokkin
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Residential Graduate Advisor
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="josh+kawinski" name="josh+kawinski">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/josh-kawinski">
#                  <img alt="Photo of Josh" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/jkawinski.png?itok=EwckVYWc" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/josh-kawinski">
#                    Josh Kawinski
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Program and Marketing Coordinator
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="mika+puseman" name="mika+puseman">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/mika-puseman">
#                  <img alt="Photo of Mika" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/mika_photo.png?itok=3JFVdrRZ" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/mika-puseman">
#                    Mika Puseman
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Coursera Course Coordinator
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="kaitlyn+rye" name="kaitlyn+rye">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/kaitlyn-rye">
#                  <img alt="Photo of Kaitlyn" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/rye_headshot_k_rye_.jpg?itok=XX1ByXmU" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/kaitlyn-rye">
#                    Kaitlyn Rye
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Coursera Graduate Program Advisor
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="people-list-group-title people-list-grid-group-title">
#                Faculty
#               </h2>
#               <div class="people-list-wrapper-grid">
#                <a id="jem+corcoran" name="jem+corcoran">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/jem-corcoran">
#                  <img alt="Jem Corcoran" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/jem_corcoran.jpg?itok=PqOlniku" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/jem-corcoran">
#                    Jem Corcoran
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Associate Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Applied Mathematics
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="anne+dougherty" name="anne+dougherty">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/anne-dougherty">
#                  <img alt="Anne Dougherty" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/anne_d_copy_copy.jpg?itok=683svKUP" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/anne-dougherty">
#                    Anne Dougherty
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Senior Instructor &amp; University of Colorado Teaching Professor • Associate Department Chair   • Undergraduate Studies Chair
#                   </div>
#                   <div class="person-departments-grid">
#                    Applied Mathematics
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="ioana+fleming" name="ioana+fleming">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/ioana-fleming">
#                  <img alt="Ioana Fleming" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/ioana_fleming_copy.jpg?itok=yYkf40ZW" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/ioana-fleming">
#                    Ioana Fleming
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Senior Instructor • Chair of Undergraduate Education
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="ami+gates" name="ami+gates">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/ami-gates">
#                  <img alt="Ami Gates Photo" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/gates_ami_small.jpeg?itok=0JcHLoOA" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/ami-gates">
#                    Ami Gates
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Teaching Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Applied Mathematics • Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="abel+iyasele" name="abel+iyasele">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/abel-iyasele-0">
#                  <img alt="Abel Iyasele Photo" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/abel_pix_2_-_abel_iyasele_small.jpeg?itok=vuK5Bvvw" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/abel-iyasele-0">
#                    Abel Iyasele
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Teaching Assistant Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Information Science • Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="geena+kim" name="geena+kim">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/geena-kim">
#                  <img alt="Geena Kim" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/geena_kim.png?itok=UXUCn7AR" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/geena-kim">
#                    Geena Kim
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Post-Baccalaureate Instructor
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="william+kuskin" name="william+kuskin">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/william-kuskin">
#                  <img alt="William Kuskin" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/william_kuskin_copy.jpg?itok=A4_t5BiM" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/william-kuskin">
#                    William Kuskin
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Professor • CEAS Associate Dean for Digital Education
#                   </div>
#                   <div class="person-departments-grid">
#                    English &amp; Engineering
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="qin+%28christine%29+lv" name="qin+%28christine%29+lv">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/qin-christine-lv">
#                  <img alt="Qin (Christine) Lv" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/qin_lv_copy.jpg?itok=4pYxNDLB" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/qin-christine-lv">
#                    Qin (Christine) Lv
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="osita+onyejekwe" name="osita+onyejekwe">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/osita-onyejekwe">
#                  <img alt="Osita Onyejekwe Photo" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/osita_small_0.jpeg?itok=1qInNoGO" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/osita-onyejekwe">
#                    Osita Onyejekwe
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Teaching Assistant Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science; Applied Mathematics
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="alan+paradise" name="alan+paradise">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/alan-paradise">
#                  <img alt="Alan Paradise" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/alan_paradise_copy.jpg?itok=EBlqQsjC" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/alan-paradise">
#                    Alan Paradise
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Assistant Teaching Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="al+pisano" name="al+pisano">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/al-pisano">
#                  <img alt="Al Pisano" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/al_pisano.jpg?itok=CGpmMoQx" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/al-pisano">
#                    Al Pisano
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Instructor
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="sriram+sankaranarayanan" name="sriram+sankaranarayanan">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/sriram-sankaranarayanan">
#                  <img alt="Sriram Sankaranarayanan" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/sriram_sankaranarayanan_copy.jpg?itok=SQyfjBzM" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/sriram-sankaranarayanan">
#                    Sriram Sankaranarayanan
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Associate Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="chris+vargo" name="chris+vargo">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/chris-vargo">
#                  <img alt="Chris Vargo" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/chris_vargo.jpeg?itok=EIpSgdeC" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/chris-vargo">
#                    Chris Vargo
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Associate Professor of Advertising and Analytics
#                   </div>
#                   <div class="person-departments-grid">
#                    College of Media, Communication and Information
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="di+wu" name="di+wu">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/di-wu">
#                  <img alt="Di Wu" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/di_wu_0_0.jpeg?itok=gug5byio" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/di-wu">
#                    Di Wu
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Teaching Assistant Professor
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science • Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="people-list-group-title people-list-grid-group-title">
#                Lecturer
#               </h2>
#               <div class="people-list-wrapper-grid">
#                <a id="dave+underwood" name="dave+underwood">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/dave-underwood">
#                  <img alt="David Underwood" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/dave_underwood_0.jpg?itok=K0vjoQwx" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/dave-underwood">
#                    Dave Underwood
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Lecturer (Retired)
#                   </div>
#                   <div class="person-departments-grid">
#                    Information Technology
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="people-list-group-title people-list-grid-group-title">
#                Student Assistant
#               </h2>
#               <div class="people-list-wrapper-grid">
#                <a id="swapnil+sethi" name="swapnil+sethi">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/swapnil-sethi">
#                  <img alt="Photo of Swapnil" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/swapnil.sethicolorado.edu-dcaf8d9c.jpg?itok=H3wTeoyu" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/swapnil-sethi">
#                    Swapnil Sethi
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Student Assistant
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="darsh+shah" name="darsh+shah">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/darsh-shah">
#                  <img alt="Photo of Darsh " class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/darsh_shah_photo.jpg?itok=OC0VGcJP" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/darsh-shah">
#                    Darsh Shah
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Student Assistant
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="lauren+walters" name="lauren+walters">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/lauren-walters">
#                  <img alt="Photo of Lauren " class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/screen_shot_2022_09_23_at_12.07.28_pm.png?itok=SZrSbECU" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/lauren-walters">
#                    Lauren Walters
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Student Assistant
#                   </div>
#                   <div class="person-departments-grid">
#                    Environmental design
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="people-list-group-title people-list-grid-group-title">
#                Lead Course Facilitator
#               </h2>
#               <div class="people-list-wrapper-grid">
#                <a id="sanjeev+sanjeev" name="sanjeev+sanjeev">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/sanjeev-sanjeev">
#                  <img alt="Photo of Sanjeev " class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/skfukxc_t1kn7isqvp9sja_5a50b47e50fb47b4b3006aa3b90c39f1_sanjeev_head_shot.jpg?itok=mzw_t0K5" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/sanjeev-sanjeev">
#                    Sanjeev Sanjeev
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Lead Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="people-list-group-title people-list-grid-group-title">
#                Course Facilitator
#               </h2>
#               <div class="people-list-wrapper-grid">
#                <a id="sana+fathima" name="sana+fathima">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/sana-fathima">
#                  <img alt="Photo of Sana" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/sana_headshot.jpg?itok=_rBdaZZu" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/sana-fathima">
#                    Sana Fathima
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="suraj+greenlund" name="suraj+greenlund">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/suraj-greenlund">
#                  <img alt="Photo of Suraj" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/1653777261900.jpg?itok=_1j9eNa2" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/suraj-greenlund">
#                    Suraj Greenlund
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="mattison+hineline" name="mattison+hineline">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/mattison-hineline">
#                  <img alt="Photo of Mattison " class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/img_20220131_171545.jpg?itok=utc6wNnz" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/mattison-hineline">
#                    Mattison Hineline
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="rakshith+jayanna" name="rakshith+jayanna">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/rakshith-jayanna">
#                  <img alt="photo of Rakshith" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/rakshith_photo.jpg?itok=jJ7hYrXY" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/rakshith-jayanna">
#                    Rakshith Jayanna
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="adithiyya+kishoore" name="adithiyya+kishoore">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/adithiyya-kishoore">
#                  <img alt="Photo of Adithiyya" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/addzy.jpeg?itok=RQToYLuX" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/adithiyya-kishoore">
#                    Adithiyya Kishoore
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="ruijiang+ma" name="ruijiang+ma">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/ruijiang-ma">
#                  <img alt="Photo of Ruijiang" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/img_6213.png?itok=fUNIKmVS" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/ruijiang-ma">
#                    Ruijiang Ma
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="neeraj+madisetty" name="neeraj+madisetty">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/neeraj-madisetty">
#                  <img alt="Photo of Neeraj" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/194469758_4168392816551791_111231886770383538_n.jpg?itok=CGtkFQXe" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/neeraj-madisetty">
#                    Neeraj Madisetty
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="ayush+pandey" name="ayush+pandey">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/ayush-pandey">
#                  <img alt="Photo of ayush" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/ayush_pandey_photograph.jpg?itok=pw6DTrFJ" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/ayush-pandey">
#                    Ayush Pandey
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="pranjal+pathak" name="pranjal+pathak">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/pranjal-pathak">
#                  <img alt="Photo of Pranjal" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/5.8._white_passport.jpg?itok=0Lfgmk0Q" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/pranjal-pathak">
#                    Pranjal Pathak
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="denis+polgul" name="denis+polgul">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/denis-polgul">
#                  <img alt="Photo of Denis" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/screen_shot_2022-10-24_at_9.55.00_am.png?itok=Tmx0ax2V" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/denis-polgul">
#                    Denis Polgul
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                   </div>
#                   <div class="person-departments-grid">
#                    Data Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="maaz+shaikh" name="maaz+shaikh">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/maaz-shaikh">
#                  <img alt="Photo of Maaz" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/2a600805_23ab_48f5_9613_984820609691.jpg?itok=MUi_uyWh" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/maaz-shaikh">
#                    Maaz Shaikh
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <a id="bofan+zheng" name="bofan+zheng">
#                </a>
#                <div class="person-view-mode-grid grid-person clearfix col-lg-4 col-md-4 col-sm-6 col-xs-12">
#                 <a href="/program/data-science/bofan-zheng">
#                  <img alt="Photo of Bofan Zheng" class="image-large_square_thumbnail" height="600" src="https://www.colorado.edu/program/data-science/sites/default/files/styles/large_square_thumbnail/public/people/bofan_photo.jpeg?itok=sNICvfbF" width="600"/>
#                 </a>
#                 <div class="person-grid-content-wrapper">
#                  <strong>
#                   <a href="/program/data-science/bofan-zheng">
#                    Bofan Zheng
#                   </a>
#                  </strong>
#                  <div class="person-view-mode-grid-content">
#                   <div class="person-job-titles-grid">
#                    Course Facilitator
#                   </div>
#                   <div class="person-departments-grid">
#                    Computer Science
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <!-- SIDEBARS -->
#           <!-- /SIDEBARS -->
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- /MAIN CONTENT -->
#      <!-- FEATURE LAYOUT CONTENT -->
#      <!-- /FEATURE LAYOUT CONTENT -->
#     </div>
#     <!-- /PAGE CONTENT -->
#     <!-- POST WIDE -->
#     <!-- /POST WIDE -->
#     <!-- AFTER CONTENT -->
#     <!-- /AFTER CONTENT -->
#     <!-- AFTER CONTENT2 -->
#     <!-- /AFTER CONTENT2 -->
#     <!-- FOOTER SECTION -->
#     <div class="footer-section background-gray-dark" id="footer-section">
#      <!-- FOOTER -->
#      <!-- /FOOTER -->
#      <!-- FOOTER MENU -->
#      <!-- /FOOTER MENU -->
#      <!-- SITE INFO -->
#      <div class="section site-info-wrapper background-black" id="site-info-wrapper">
#       <div class="site-info" id="site-info">
#        <div class="container">
#         <footer class="row region region-site-info footer-2col" id="site-footer">
#          <div class="col-lg-8 col-md-8" id="site-footer-content">
#           <div class="block block-cu-site-info has-block-title block-cu-site-info-site-info" id="block-cu-site-info-site-info">
#            <div class="block-inner-wrapper block-inner clearfix">
#             <h2 class="block-title">
#              <a href="/program/data-science/">
#               Master of Science in Data Science
#              </a>
#             </h2>
#             <div class="content">
#              <p>
#               Offered through an interdisciplinary partnership, data science at CU Boulder is
#               <br/>
#               delivered by the Departments of Applied Mathematics, Computer Science,
#               <br/>
#               and Information Science and awarded by the
#               <a href="https://www.colorado.edu/graduateschool/">
#                Graduate School
#               </a>
#               .
#              </p>
#              <p>
#               <a href="mailto:datascience@colorado.edu">
#                datascience@colorado.edu
#               </a>
#               <br/>
#               303-735-4114 (Monday - Friday 8:30 AM - 5:00 PM MST)
#              </p>
#              <p>
#               <a class="button button-regular button-gold" href="https://www.linkedin.com/company/cu-boulder-data-science/?viewAsMember=true">
#                <i class="fa fa-linkedin">
#                </i>
#               </a>
#               <a class="button button-regular button-gold" href="https://instagram.com/cuboulderdatascience?igshid=NzNkNDdiOGI=">
#                <i class="fa fa-instagram">
#                </i>
#               </a>
#               <a class="button button-regular button-gold" href="https://www.youtube.com/channel/UCaUZ1BJM35vPZORTLx5wbSQ">
#                <i class="fa fa-youtube">
#                </i>
#               </a>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="col-lg-4 col-md-4" id="cu-footer">
#           <p>
#            <a href="//www.colorado.edu">
#             <img alt="University of Colorado Boulder" class="beboulder" src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/images/beboulder/be-boulder-white.svg"/>
#            </a>
#           </p>
#           <p>
#            <strong>
#             <a class="cu-boulder-homepage-link" href="http://www.colorado.edu">
#              University of Colorado Boulder
#             </a>
#            </strong>
#            <br/>
#            © Regents of the University of Colorado
#            <br/>
#            <span class="required-links">
#             <a href="http://www.colorado.edu/about/privacy-statement">
#              Privacy
#             </a>
#             •
#             <a href="http://www.colorado.edu/about/legal-trademarks">
#              Legal &amp; Trademarks
#             </a>
#             •
#             <a href="http://www.colorado.edu/map">
#              Campus Map
#             </a>
#            </span>
#           </p>
#          </div>
#         </footer>
#        </div>
#       </div>
#      </div>
#      <!-- /SITE INFO -->
#     </div>
#    </div>
#   </div>
#   <div class="cu-share-sidebar">
#    <ul class="soc social-links-48">
#    </ul>
#   </div>
#   <div id="cu_back_to_top">
#    <a href="#page" title="Back to Top">
#     Return to the top of the page
#    </a>
#   </div>
#   <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/backstretch/bs.js?rm4bdq" type="text/javascript">
#   </script>
#   <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/features/cu_search/js/cu-search.js?rm4bdq" type="text/javascript">
#   </script>
#   <script src="https://www.colorado.edu/program/data-science/profiles/express/themes/ucb/js/track-focus.js?rm4bdq" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# jQuery(document).ready(function () { if (!Modernizr.svgasimg) {
#   jQuery("img#logo").attr("src", "https://www.colorado.edu/program/data-science/profiles/express/themes/cumodern/logo.png");} });
# //--><!]]>
#   </script>
#   <script src="https://www.colorado.edu/program/data-science/profiles/express/modules/custom/cu_back_to_top/cu_back_to_top.js?rm4bdq" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# Now lets try to find the Faculty roles such as Leadership, Management etc.

# %%
soup.find_all(class_="people-list-group-title people-list-grid-group-title")
# Out:
# [<h2 class="people-list-group-title people-list-grid-group-title">Program Leadership</h2>,
#  <h2 class="people-list-group-title people-list-grid-group-title">Interdisciplinary Leadership</h2>,
#  <h2 class="people-list-group-title people-list-grid-group-title">Program Management</h2>,
#  <h2 class="people-list-group-title people-list-grid-group-title">Faculty</h2>,
#  <h2 class="people-list-group-title people-list-grid-group-title">Lecturer</h2>,
#  <h2 class="people-list-group-title people-list-grid-group-title">Student Assistant</h2>,
#  <h2 class="people-list-group-title people-list-grid-group-title">Lead Course Facilitator</h2>,
#  <h2 class="people-list-group-title people-list-grid-group-title">Course Facilitator</h2>]

# %% [markdown]
# Wondering how I was able to figure out the class? I understand it's hard to view the structure to print statements. You can simply right click on the web page and choose 'Inspect element'. Now you will be able to view the structure better.

# %%
contents = soup.find(id="content")

# %%
# Get the tags that has details of jobs
job_tags = contents.select(".person-job-titles-grid")
jobs = [pt.get_text() for pt in job_tags]

# %%
# Get the tags that has details of names
names = contents.select('strong')
names = [nm.get_text() for nm in names]

# %%
# Create a dataframe
import pandas as pd
faculty = pd.DataFrame({
    "Names":names,
    "Position": jobs

})

# %%
faculty
# Out:
#                       names                                           Position
# 0                 Jane Wall                                   Faculty Director
# 1            Bobby Schnabel              Department External Chair • Professor
# 2           Brian Zaharatos  Director of the Professional Master’s Degree •...
# 3               Nick Dokkin                       Residential Graduate Advisor
# 4             Josh Kawinski                  Program and Marketing Coordinator
# 5              Mika Puseman                        Coursera Course Coordinator
# 6               Kaitlyn Rye                 Coursera Graduate Program Advisor
# 7              Jem Corcoran                                Associate Professor
# 8            Anne Dougherty  Senior Instructor & University of Colorado Tea...
# 9             Ioana Fleming  Senior Instructor • Chair of Undergraduate Edu...
# 10                Ami Gates                                 Teaching Professor
# 11             Abel Iyasele                       Teaching Assistant Professor
# 12                Geena Kim                      Post-Baccalaureate Instructor
# 13           William Kuskin  Professor • CEAS Associate Dean for Digital Ed...
# 14       Qin (Christine) Lv                                          Professor
# 15          Osita Onyejekwe                       Teaching Assistant Professor
# 16            Alan Paradise                       Assistant Teaching Professor
# 17                Al Pisano                                         Instructor
# 18  Sriram Sankaranarayanan                                Associate Professor
# 19              Chris Vargo   Associate Professor of Advertising and Analytics
# 20                    Di Wu                       Teaching Assistant Professor
# 21           Dave Underwood                                 Lecturer (Retired)
# 22            Swapnil Sethi                                  Student Assistant
# 23               Darsh Shah                                  Student Assistant
# 24           Lauren Walters                                  Student Assistant
# 25          Sanjeev Sanjeev                            Lead Course Facilitator
# 26             Sana Fathima                                 Course Facilitator
# 27          Suraj Greenlund                                 Course Facilitator
# 28        Mattison Hineline                                 Course Facilitator
# 29         Rakshith Jayanna
# 30       Adithiyya Kishoore                                 Course Facilitator
# 31              Ruijiang Ma                                 Course Facilitator
# 32         Neeraj Madisetty                                 Course Facilitator
# 33             Ayush Pandey                                 Course Facilitator
# 34           Pranjal Pathak                                 Course Facilitator
# 35             Denis Polgul
# 36              Maaz Shaikh                                 Course Facilitator
# 37              Bofan Zheng                                 Course Facilitator

# %% [markdown]
# Congratulations! You have successfully completed a tutorial on Web scraping!

# %% [markdown]
# This tutorial is prepared by Ajay Sadananda
