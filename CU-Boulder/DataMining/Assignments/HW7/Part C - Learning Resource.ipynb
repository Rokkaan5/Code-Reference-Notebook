# %% [markdown]
# # Part C - Learning Resource

# %% [markdown]
# Identify ONE resource (a paper, blog, video, slide, real-life story, etc.) for each item listed below

# %% [markdown]
# Post your resources with a short description to the discussion board. Take a screenshot of your post, convert it to a pdf, and submit it to canvas.

# %% [markdown]
# ## Topic 1

# %% [markdown]
# Curse of Dimensionality: Find a resource that explains the Curse of Dimensionality, and demonstrates how high dimensionality affects the clustering methods we learned.

# %% [markdown]
# > Link (idea1):https://github.com/ageron/handson-ml2/blob/master/08_dimensionality_reduction.ipynb

# %% [markdown]
# This resource is ...

# %% [markdown]
# I like this resource because ...

# %% [markdown]
# ## Topic 2

# %% [markdown]
# Agglomerative: Find a comprehensive tutorial that introduces the topic of hierarchical clustering and uses Agglomerative method to demonstrate the process.

# %% [markdown]
# > Link:

# %% [markdown]
# This resource is...

# %% [markdown]
# I like this resource because...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d0822df1-81f8-44ca-a85c-2487d19b37ca' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
