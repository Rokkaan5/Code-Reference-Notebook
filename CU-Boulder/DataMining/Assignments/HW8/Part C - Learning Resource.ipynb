# %% [markdown]
# # Part C - Learning Resource

# %% [markdown]
# Identify ONE resource (a paper, blog, video, slide, real-life story, etc.) for each item listed below

# %% [markdown]
# Post your resources with a short description to the discussion board. Take a screenshot of your post, convert it to a pdf, and submit it to canvas.

# %% [markdown]
# ## Topic 1

# %% [markdown]
# Constraint Apriori: Find a resource that explains the Constraint Apriori, and how the constraints help to improve the efficiency

# %% [markdown]
# > Link:

# %% [markdown]
# This resource is ...

# %% [markdown]
# I like this resource because ...

# %% [markdown]
# ## Topic 2

# %% [markdown]
# Lift: Find a comprehensive tutorial that introduces how the concept of Lift is addressed in Association Rules.

# %% [markdown]
# > Link:

# %% [markdown]
# This resource is...

# %% [markdown]
# I like this resource because...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=71e1cc52-a7ef-4aeb-bc30-d1f6dccab5a7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
