# %% [markdown]
# # Part A - Reasoning

# %% [markdown]
# Answer these questions as you were asked during an interview: Don't talk too less, and don't talk too much!

# %% [markdown]
# ## Question 1

# %% [markdown]
# Explain why it is impossible to do FP analysis for all items in Walmart

# %% [markdown]
# The only reason why I can think of why FP analysis on all items in Walmart is "impossible" is because any form of FP analysis requires (at least) one database scan, and scanning a transaction database of all items in Walmart would probably require a lot of computation power (let alone multiple scans).

# %% [markdown]
# (But I'm not completely sure/confident of this answer.)

# %% [markdown]
# ## Question 2

# %% [markdown]
# Explain each with examples

# %% [markdown]
# ### 1. Monotone

# %% [markdown]
# Monotonicity is when all supersets of an itemset satisfy a rule constraint.

# %% [markdown]
# Example: ...

# %% [markdown]
# ### 2. Antimonotone

# %% [markdown]
# Antimonotonicity is when all supersets of an itemset violate a rule constraint.

# %% [markdown]
# Example: ...

# %% [markdown]
# ### 3. Convertible monotone

# %% [markdown]
# Convertible monotonicity is when an itemset is monotonic if ordered in a specific order.

# %% [markdown]
# Example: ...

# %% [markdown]
# ### 4. Convertible antimonotone

# %% [markdown]
# Convertible antimonotonicity (similar to convertible monotone) is when an itemset is antimonotonic if ordered in a specific order.

# %% [markdown]
# Example: ...

# %% [markdown]
# ### 5. Strongly convertible

# %% [markdown]
# Strongly convertible means the set is both convertible monotonic and convertible antimonotonic.

# %% [markdown]
# Example: ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=71e1cc52-a7ef-4aeb-bc30-d1f6dccab5a7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
