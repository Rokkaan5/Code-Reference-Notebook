# %% [markdown]
# # Part C - Reading

# %% [markdown]
# > Chosen Paper title: Data Preprocessing for Supervised Leaning

# %% [markdown]
# ## Question 1

# %% [markdown]
# What is the problem addressed? Why is the problem important and challenging?

# %% [markdown]
# Optimizing the data preprocessing step so that machine learning models consistently have the best training data possible.

# %% [markdown]
# The common problems encountered in data cleaning for machine learning models (dealing with outliers, missing data, mixed (both numerical and categorical) data, etc.)

# %% [markdown]
# ## Question 2

# %% [markdown]
# A high-level, brief description of the proposed solution (no need to include the details).

# %% [markdown]
# The paper proposes some commonly used algorithms for each data preprocessing step to optimize the quality of the data that one would have in the end.

# %% [markdown]
# - Outlier detection

# %% [markdown]
# - Dealing with unknown feature values

# %% [markdown]
# - Discretization

# %% [markdown]
# - Normalization techniques

# %% [markdown]
# - Feature selection

# %% [markdown]
# - Feature construction

# %% [markdown]
# ## Question 3

# %% [markdown]
# Discuss one point that you agree most with the author in detail. What is it, and why do you agree with the author?

# %% [markdown]
# Many parts of the data preprocessing process have a major influence on the performance of a machine learning model. I agree with that point because of my experience in the research assistant position. Another one of the main reasons why I decided to pursue a grad education in Data Science was because I had fun exploring the different effects of using (training) data made with different preprocessing methods (which evaluated by evaluating the feature importance and other aspects of the model I built). I experimented with different feature selections and normalizing vs. not normalizing the data. And each training set had different effects on the model's structure and performance.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ec55871d-6907-4dc4-875f-7292258a544e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
