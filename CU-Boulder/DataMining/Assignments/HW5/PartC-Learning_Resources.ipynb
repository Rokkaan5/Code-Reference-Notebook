# %% [raw]
# ---
# title: "HW5: Part C - Learning Resource"
# author: Jasmine Kobayashi
# format:
#   html:
#     code-fold: false
# execute:
#   output: true
# toc: true
# ---

# %% [markdown]
# **Identify ONE resource (a paper, blog, video, slide, real-life story, etc.) for each item listed below:**

# %% [markdown]
# ## Topic 1

# %% [markdown]
# ## Topic 2
