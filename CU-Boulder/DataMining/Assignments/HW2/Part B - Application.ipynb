# %% [markdown]
# # Part B - Application

# %% [markdown]
# # Question 1 (job-seeking dataset)

# %% [markdown]
# You have collected the data for assisting students in job seeking (Assignment 01, Part B, Prompt 1) and saved it as a .csv file. Apply the Python pandas package to the data you have collected, demonstrate how we can use it to get a better understanding of the data.

# %% [markdown]
# > Note from Jasmine: I decided to use a different dataset than the one I created in HW1 for the sake of this HW problem. This was because the dataset I built in HW1 was very limited in information (and for instance did NOT have any numerical data because the "salary" column contained much more different salary information than I was expecting). So I selected a data set of the same topic but with much more useable information to accomplish this part of the assignment.

# %% [markdown]
# ## Read in the data

# %%
#import necessary libraries
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('jobpostings.csv')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
print('total # of rows in df:',len(df))
df.head()
# Out:
# total # of rows in df: 49003
#                                            Job Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                      Job Description  \
# 0  AMERIA Investment Consulting Company is seekin...
# 1                                                NaN
# 2  Public outreach and strengthening of a growing...
# 3  The LEAD (Local Enhancement and Development fo...
# 4                                                NaN
#
#                                       Company Name  \
# 0             AMERIA Investment Consulting Company
# 1  International Research & Exchanges Board (IREX)
# 2        Caucasus Environmental NGO Network (CENN)
# 3                                     Manoff Group
# 4                           Yerevan Brandy Company
#
#                                             Location  \
# 0                                   Yerevan, Armenia
# 1  IREX Armenia Main Office; Yerevan, Armenia \r\...
# 2                                   Yerevan, Armenia
# 3                                Manila, Philippines
# 4                                   Yerevan, Armenia
#
#                                  Company Description Salary
# 0                                                NaN    NaN
# 1  The International Research & Exchanges Board (...    NaN
# 2  The Caucasus Environmental NGO Network is a\r\...    NaN
# 3                                                NaN    NaN
# 4                                                NaN    NaN

# %% [markdown]
# ## Basic info of the dataset

# %% [markdown]
# Objects, attributes, datatype of attributes, etc.

# %% [markdown]
# Reminder to self (copied from class slides and class recommended textbook):

# %% [markdown]
# - Object - entity: abstract data structure with certain attributes/features/dimensions/variables

# %% [markdown]
# - Attributes - characteristic or feature of a data object (Categorical: nominal, binary, ordinal; Numerical: interval-scaled, ratio-scaled, discrete or continuous.

# %%
df.Salary.value_counts()
# Out:
# Competitive                                                                                                                                                                            1298
# Highly competitive                                                                                                                                                                      588
# Based on previous salary history, experience and\r\nprevailing market rates for comparable positions.                                                                                   270
# Negotiable                                                                                                                                                                              269
# Attractive                                                                                                                                                                              184
#                                                                                                                                                                                        ...
# Competitive compensation with emphasize on\r\nincentive pay plan, bonus opportunities; extensive training for\r\nprofessional development and advancement.                                1
# Competitive salary based on qualifications,\r\nprofessional development opportunities including training materials,\r\ntrainings and certification opportunities.                         1
# Starting 350,000 AMD, depends on qualification +\r\nbenefits, including medical insurance, fitness program, English classes,\r\nprofessional improvement seminars and loan program.       1
# Competative, with possibility of professional and\r\ncareer growth in the company.                                                                                                        1
# Negotiable salary.                                                                                                                                                                        1
# Name: Salary, Length: 2692, dtype: int64

# %%
df.groupby(['Salary'],as_index=False).filter(lambda x: len(x) >=5).Salary.value_counts()
# Out:
# Competitive                                                                                                                                                                    1298
# Highly competitive                                                                                                                                                              588
# Based on previous salary history, experience and\r\nprevailing market rates for comparable positions.                                                                           270
# Negotiable                                                                                                                                                                      269
# Attractive                                                                                                                                                                      184
#                                                                                                                                                                                ...
# VivaCell-MTS offers competitive compensation,\r\nincluding various benefits, as well as trainings and potential for career\r\nadvancement.                                        5
# Competitive + benefits, including medical\r\ninsurance, English/Russian classes, professional improvement seminars and\r\na fully stocked kitchen for breakfast and snacks.       5
# Ranging from 100,000 to 2,000,000 AMD, according\r\nto the S grade of Ameriabank remuneration scheme.                                                                             5
# Attractive, depends on experience and\r\nqualifications.                                                                                                                          5
# Depending on skills and experience.                                                                                                                                               5
# Name: Salary, Length: 260, dtype: int64

# %%
# objects = available job positions 
# attributes = company name (nominal categorical type), Location (nominal), salary

# %% [markdown]
# ## For a categorical attribute:

# %% [markdown]
# ### Value Counts

# %% [markdown]
# ## For a numerical attribute

# %% [markdown]
# ### Data basics: Min, Max

# %% [markdown]
# ### Data Central Tendency: Mean, Median, Mode

# %% [markdown]
# ### Data Dispersion: Range, Midrange, Quartiles, IQR, Variance, Std, Outliers

# %% [markdown]
# ## What knowledge may be mined from this data set?

# %% [markdown]
# ## How would the knowledge be useful in some applications?

# %% [markdown]
# # Question 2 (News data)

# %% [markdown]
# You have collected data of news (Assignment 01, Part B, Prompt 2) and saved it as a .csv file. Perform text processing (refer tutorial). Label the data as positive/negative sentiments.

# %% [markdown]
# You should prepare a tutorial for this part. In the tutorial, you use the dataset, write some code, print the output, and write some explanations.

# %% [markdown]
# > Some potentially useful feedback: Some people mentioned this in class, but I would like to relay my similar sentiments so that there can be more ideas for assignments in future classes (since our assignments are also a little experimental). I definitely think it would have been a lot more useful to know if I was going to use the datasets I was building in HW1 in future assignments. If I had known such information, then I would have approached the problem much differently and probably would've spent more time carefully building a nice useable dataset on that portion of the homework (rather than polishing the other reading and writing portions of the assignment).

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b69dcf2a-968b-4990-883d-3ab139ec5f5e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
