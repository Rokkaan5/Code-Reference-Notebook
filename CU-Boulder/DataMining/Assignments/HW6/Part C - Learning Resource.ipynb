# %% [markdown]
# # Part C - Learning Resource

# %% [markdown]
# Identify ONE resource (a paper, blog, video, slide, real-life story, etc.) for each item listed below

# %% [markdown]
# Post your resources with a short description to the discussion board. Take a screenshot of your post, convert it to a pdf, and submit it to canvas.

# %% [markdown]
# ## Topic 1

# %% [markdown]
# Assumptions matter: Find a resource that explains the assumptions of linear regression, and demonstrates the consequences if assumptions are not met for the analysis.

# %% [markdown]
# > Link:

# %% [markdown]
# This resource is ...

# %% [markdown]
# I like this resource because ...

# %% [markdown]
# ## Topic 2

# %% [markdown]
# Overfitting: Find a comprehensive tutorial that introduces the topic of overfitting and the techniques that help to prevent overfitting.

# %% [markdown]
# > Link:

# %% [markdown]
# This resource is...

# %% [markdown]
# I like this resource because...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=913e9dd0-cce1-40b6-9007-807b6e1dcb4a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
